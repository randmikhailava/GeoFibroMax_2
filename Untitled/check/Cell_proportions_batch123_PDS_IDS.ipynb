# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr, wilcoxon
import plotly.express as px
import plotly.graph_objects as go
import nbformat

from scipy.stats import ttest_ind, f_oneway
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib_venn import venn2
import os
from scipy.stats import mannwhitneyu

# %%
cell_proportions=pd.read_csv("/Users/nikamikhailava/Desktop/batch_merged_new/bp_res_mid_lvl_ct_updated_ct_fraction_batch_3.csv")
fibr_gene_expression_modified=pd.read_csv("/Users/nikamikhailava/Desktop/batch_merged_new/fibroblasts_gene_expression_data_new_batch_three_merged_transposed.csv")
print(len(fibr_gene_expression_modified))
cell_proportions=pd.read_csv("/Users/nikamikhailava/Desktop/batch_merged_new/bp_res_mid_lvl_ct_updated_ct_fraction_batch_3.csv")
fibr_gene_expression_modified = pd.merge(
    fibr_gene_expression_modified,
    cell_proportions,
    on="dcc_filename",
    how="inner"  # or "left", "right", "outer" depending on your needs
)
clinical_data=pd.read_csv("/Users/nikamikhailava/Desktop/batch_merged/9_eyemt_patient_clinical_data_new.csv")
fibr_gene_expression_modified["Patient"]=fibr_gene_expression_modified["Sample"].str.extract(r'(S\d+)')
fibr_gene_expression_modified=fibr_gene_expression_modified.merge(clinical_data[["Patient","PFS_quartile_b123","OS_quartile_b123"]],on="Patient", how="left")
fibr_gene_expression_cell_abundance=fibr_gene_expression_modified.merge(cell_proportions, on="dcc_filename", how="left")
# Out:
# 1130

# %%
cell_proportions["Segment_geomx"]
# Out:
# 0          tsi
# 1          tsi
# 2          tsi
# 3          tsi
# 4          tsi
#          ...
# 1144       tsi
# 1145       tsi
# 1146       tsi
# 1147    stroma
# 1148    stroma
# Name: Segment_geomx, Length: 1149, dtype: object

# %%
cell_types=[
 'Tcells_reg',
 'Bcells',
 'Fibroblasts',
 'NKcells',
 'Tcells_CD8',
 'Tcells_CD4',
 'Macrophages_Monocytes',
 'DCs',
 'Endothelial_cells',]

# %%
fibr_gene_expression_cell_abundance["PFS_HL_group"] = fibr_gene_expression_cell_abundance["PFS_quartile_b123"].apply(
    lambda x: "Low" if x in [1, "1", 2, "2"] else ("High" if x in [3, "3", 4, "4"] else None)
)
fibr_gene_expression_cell_abundance["OS_HL_group"] = fibr_gene_expression_cell_abundance["OS_quartile_b123"].apply(
    lambda x: "Low" if x in [1, "1", 2, "2"] else ("High" if x in [3, "3", 4, "4"] else None)
)

# %%
# Properly filter for stroma + Segment_geomx == 'tsi'
stroma_cell_abundance = cell_proportions[
    (cell_proportions['Segment'] == 'stroma') & 
    (cell_proportions['Segment_geomx'] == 'stroma')
]

# Seems to be the same filter as above — do you really need both?
stroma_tsi_cell_abundance = cell_proportions[
    (cell_proportions['Segment'] == 'stroma') & 
    (cell_proportions['Segment_geomx'] == 'tsi')
]

# Group by Sample_y and compute mean abundance
average_stroma_cell_abundance_stroma = stroma_cell_abundance.groupby('Sample')[cell_types].mean()
average_stroma_cell_abundance_stroma["Segment_geomx"] = "stroma"
average_stroma_cell_abundance_tsi = stroma_tsi_cell_abundance.groupby('Sample')[cell_types].mean()
average_stroma_cell_abundance_tsi["Segment_geomx"] = "tsi"

# %%
combined=pd.concat([average_stroma_cell_abundance_stroma,average_stroma_cell_abundance_tsi])

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
from matplotlib.patches import Patch

# =========================
# 1. Statistical testing per cell type
# =========================
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()
    
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")
    
    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value,
        "mean_total": pd.concat([group_stroma, group_tsi]).mean()
    }

res_df = pd.DataFrame(results).T

# FDR correction
res_df["p_adj"] = multipletests(res_df["p_value"], method="fdr_bh")[1]

# =========================
# 2. Sort cell types by total mean abundance
# =========================
sorted_cells = res_df.sort_values(by="mean_total", ascending=False).index.tolist()

# =========================
# 3. Prepare data for plotting
# =========================
plot_data = pd.melt(
    combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])],
    id_vars=["Segment_geomx"],
    value_vars=sorted_cells,
    var_name="Cell_Type",
    value_name="Expression"
)

# =========================
# 4. Plot
# =========================
plt.figure(figsize=(14, 8))
palette = {"stroma":"#9e82f2", "tsi": "#3ab7be"}

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", 
    data=plot_data, palette=palette, linewidth=1.5, order=sorted_cells
)

# =========================
# 5. Add FDR-adjusted significance stars
# =========================
y_max = plot_data["Expression"].max()
for i, cell in enumerate(sorted_cells):
    p_adj = res_df.loc[cell, "p_adj"]
    if p_adj < 0.05:
        if p_adj >= 0.01:
            star = "*"
        elif p_adj >= 0.001:
            star = "**"
        else:
            star = "***"
        ax.text(i, y_max*0.95, star, ha="center", va="center", fontsize=14, fontweight="bold", color="black")

# =========================
# 6. Labels and formatting
# =========================
plt.title("Cell Abundance in Distant Stroma vs TSI (FDR-adjusted) in PRE and POST samples", fontsize=16, fontweight="bold")
plt.xlabel("Cell Type")
plt.ylabel("Expression Level")
plt.xticks(rotation=60, fontsize=12)

# =========================
# 7. Legends
# =========================
# Segment legend (stroma vs TSI)
handles, labels = ax.get_legend_handles_labels()
segment_handles = handles[:2]  # first two are stroma/tsi
segment_labels = ["stroma", "tsi"]
legend1 = ax.legend(handles=segment_handles, labels=segment_labels,
                    title="Segments", title_fontsize=13, fontsize=12,
                    loc='upper left', bbox_to_anchor=(1.0, 0.85), frameon=False)

# Add significance legend (FDR stars) without removing segment legend
'''
signif_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   FDR < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  FDR < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** FDR < 0.001"),
]
ax.add_artist(legend1)  # keep first legend
ax.add_artist(plt.legend(handles=signif_legend, loc="upper left", bbox_to_anchor=(1.0, 1.05), frameon=False))
'''

plt.tight_layout()
plt.show()

# %%
import math

num_plots = len(cell_types)
ncols = 3
nrows = math.ceil(num_plots / ncols)

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(14, nrows * 6))
axes = axes.flatten()

for i, cell in enumerate(cell_types):
    combined = combined.reset_index(drop=True)
    ax = axes[i]

    # Extract data
    group_stroma = combined[combined["Segment_geomx"] == "stroma"][cell]
    group_tsi = combined[combined["Segment_geomx"] == "tsi"][cell]
    group_stroma = group_stroma.dropna()
    group_tsi = group_tsi.dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative='two-sided')

    # Plot
    sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
    sns.stripplot(x="Segment_geomx", y=cell, data=combined, color='gray', alpha=0.6, jitter=True, ax=ax)

    # Label
    ax.set_title(f"{cell} proportion in stromal segments(p = {p_value:.4f})", fontsize=10)
    ax.set_xlabel("GeoMX Segment")
    ax.set_ylabel("Cell Proportion")

# Remove unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_8365/3494953762.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Segment_geomx", y=cell, data=combined, ax=ax, palette=["lightgreen", "lightblue"])

# %%
# Store p-values in a dict
pvals = {}

for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()
    
    # Mann-Whitney test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")
    pvals[cell] = p_value

# Convert to DataFrame for heatmap
pval_df = pd.DataFrame.from_dict(pvals, orient="index", columns=["p_value"])
pval_df["-log10(p)"] = -np.log10(pval_df["p_value"])   # easier to visualize

# Create heatmap matrix (1 row, many columns)
heatmap_data = pval_df[["-log10(p)"]].T

# Plot
plt.figure(figsize=(len(cell_types)*0.6, 3))
ax = sns.heatmap(
    heatmap_data,
    annot=False,
    cmap="Blues",
    cbar_kws={'label': '-log10(p-value)'}
)

# Add stars for significance
for j, cell in enumerate(heatmap_data.columns):
    if pval_df.loc[cell, "p_value"] < 0.05:
        ax.text(j+0.5, 0.5, "*", color="red", ha="center", va="center", fontsize=16)

ax.set_xticklabels(heatmap_data.columns, rotation=45, ha="right")
ax.set_yticklabels(["Significance"], rotation=0)
plt.title("Mann-Whitney U test significance across cell types")
plt.tight_layout()
plt.show()

# %%
from matplotlib.lines import Line2D

# Store results
results = {}

for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()
    
    # Mann-Whitney test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")
    
    # Mean difference (stroma - tsi)
    mean_diff = group_stroma.mean() - group_tsi.mean()
    
    results[cell] = {"p_value": p_value, "mean_diff": mean_diff}

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# Make heatmap matrix (1 row with mean differences as values)
heatmap_data = res_df[["mean_diff"]].T

# Plot
plt.figure(figsize=(len(cell_types)*0.6, 3))
ax = sns.heatmap(
    heatmap_data,
    annot=False,
    cmap="coolwarm",  # blue = lower in stroma, red = higher in stroma
    center=0,
    #cbar_kws={'label': 'Mean difference (Stroma - TSI)'}
)

# Add stars for significant results
for j, cell in enumerate(heatmap_data.columns):
    if res_df.loc[cell, "p_value"] < 0.05:
        ax.text(j+0.5, 0.5, "*", color="black", ha="center", va="center", fontsize=16)

ax.set_xticklabels(heatmap_data.columns, rotation=45, ha="right")
ax.set_yticklabels(["Mean Difference"], rotation=0)
plt.title("Stroma vs TSI: Mean difference with significance")
#plt.legend([ "*  p < 0.05" ], loc='upper left', bbox_to_anchor=(1, 1))

custom_legend = [Line2D([0], [0], color="white", marker="*", linestyle="None",
                        markerfacecolor="black", markersize=12, label="p < 0.05")]

ax.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(1.16, 1.1))

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from matplotlib.lines import Line2D
from matplotlib.text import Text
from matplotlib.patches import Patch

# Store results
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# Heatmap data (two rows: stroma & tsi)
heatmap_data = res_df[["stroma_mean", "tsi_mean"]].T
heatmap_data.index = ["Stroma", "TSI"]

# Plot heatmap
plt.figure(figsize=(len(cell_types)*0.6, 4))
ax = sns.heatmap(
    heatmap_data,
    annot=True, fmt=".2f",
    cmap="viridis",
    cbar_kws={'label': 'Mean cell proportion'},
    linewidths=0.5, linecolor="gray"
)

# Add stars for significant results
for j, cell in enumerate(heatmap_data.columns):
    p = res_df.loc[cell, "p_value"]
    if p < 0.05:
        # place star between the two rows (at y=0.5)
        ax.text(j+0.5, 0.4, "*" if p>=0.01 else "**" if p>=0.001 else "***",
                color="white", ha="center", va="center", fontsize=14, fontweight="bold")
        ax.text(j+0.5, 1.4, "*" if p>=0.01 else "**" if p>=0.001 else "***",
                color="white", ha="center", va="center", fontsize=14, fontweight="bold")

# Labels and title
ax.set_xticklabels(heatmap_data.columns, rotation=45, ha="right")
ax.set_yticklabels(heatmap_data.index, rotation=0)
plt.title("Cell proportions in Stroma vs TSI with significance")


custom_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   p < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  p < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** p < 0.001")
]

ax.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(1.1, 1.1),frameon=False)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from matplotlib.patches import Patch

# Store results
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# Create a DataFrame for plotting
plot_data = pd.melt(combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])], 
                    id_vars=["Segment_geomx"], 
                    value_vars=cell_types, 
                    var_name="Cell_Type", 
                    value_name="Expression")

# Plot boxplots
plt.figure(figsize=(12, 6))

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data, 
    palette=["lightblue", "salmon"], linewidth=1.5
)

# Add significance stars
for i, cell in enumerate(cell_types):
    p = res_df.loc[cell, "p_value"]
    if p < 0.05:
        # Place star above the boxplot (adjust the position slightly)
        ax.text(i, ax.get_ylim()[1] * 0.95, "*" if p>=0.01 else "**" if p>=0.001 else "***",
                color="black", ha="center", va="center", fontsize=14, fontweight="bold")

# Labels and title
plt.title("Cell Type Abundance in Stromal Segments in Distant Stroma vs TSI")
plt.xlabel("Cell Type")
plt.xticks(fontsize=10,rotation=45)
plt.ylabel("Expression Level")

# Create custom legend for significance
custom_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   p < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  p < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** p < 0.001")
]
plt.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(0.98, 1), frameon=False)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from matplotlib.patches import Patch

# Store results
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# Create a DataFrame for plotting
plot_data = pd.melt(combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])], 
                    id_vars=["Segment_geomx"], 
                    value_vars=cell_types, 
                    var_name="Cell_Type", 
                    value_name="Expression")

# Plot boxplots
plt.figure(figsize=(12, 8))

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data, 
    palette=["lightblue", "salmon"], linewidth=1.5
)

# Add significance stars
for i, cell in enumerate(cell_types):
    p = res_df.loc[cell, "p_value"]
    if p < 0.05:
        # Place star above the boxplot (adjust the position slightly)
        ax.text(i, ax.get_ylim()[1] * 0.95, "*" if p>=0.01 else "**" if p>=0.001 else "***",
                color="black", ha="center", va="center", fontsize=14, fontweight="bold")

# Labels and title
plt.title("Cell Abundance in Stromal Segments in Distant Stroma vs TSI",fontsize=16)
plt.xlabel("Cell Type")
plt.xticks(fontsize=12, rotation=60)
plt.ylabel("Expression Level")

# Create custom legend for significance
custom_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   p < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  p < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** p < 0.001")
]

# Add legend for the significance stars
ax.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

# Adjust the legend for stroma and tsi (automatically created by hue)
handles, labels = ax.get_legend_handles_labels()
# Remove the 'hue' legend entry for the 'Cell_Type' (because it is already handled in the plot)
handles = [handles[0], handles[1]]  # Stroma and TSI colors
labels = ["Stroma", "TSI"]

# Add the custom color legend
ax.legend(handles=handles, labels=labels, loc='upper left', bbox_to_anchor=(1.0, 0.85), title="Segments",title_fontsize=13,fontsize=12)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from matplotlib.patches import Patch

# Store results
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# Create a DataFrame for plotting
plot_data = pd.melt(combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])], 
                    id_vars=["Segment_geomx"], 
                    value_vars=cell_types, 
                    var_name="Cell_Type", 
                    value_name="Expression")

# Plot boxplots
plt.figure(figsize=(12, 8))

# Define custom colors for stroma and TSI
#palette = {"stroma": "#65D5DF", "tsi": "#DB615C"} 
 # Green for stroma, tomato red for TSI

palette={"tsi": "#3ab7be", "stroma":"#9e82f2"}

# Create the boxplot
ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data, 
    palette=palette, linewidth=1.5
)

# Add significance stars
for i, cell in enumerate(cell_types):
    p = res_df.loc[cell, "p_value"]
    if p < 0.05:
        # Place star above the boxplot (adjust the position slightly)
        ax.text(i, ax.get_ylim()[1] * 0.95, "*" if p>=0.01 else "**" if p>=0.001 else "***",
                color="black", ha="center", va="center", fontsize=14, fontweight="bold")

# Labels and title
plt.title("Cell Abundance in Stromal Segments in Distant Stroma vs TSI", fontsize=16)
plt.xlabel("Cell Type")
plt.xticks(fontsize=12, rotation=60)
plt.ylabel("Expression Level")

# Create custom legend for significance
custom_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   p < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  p < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** p < 0.001")
]

# Add legend for the significance stars
ax.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

# Adjust the legend for stroma and tsi (automatically created by hue)
handles, labels = ax.get_legend_handles_labels()
# Remove the 'hue' legend entry for the 'Cell_Type' (because it is already handled in the plot)
handles = [handles[0], handles[1]]  # Stroma and TSI colors
labels = ["stroma", "tsi"]

# Add the custom color legend
ax.legend(handles=handles, labels=labels, loc='upper left', bbox_to_anchor=(1.0, 0.85), title="Segments", title_fontsize=13, fontsize=12)

# Tight layout to ensure everything fits
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from matplotlib.patches import Patch

# -----------------------------
# 1. Compute stats per cell type
# -----------------------------
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# -----------------------------
# 2. Sort cell types by stroma mean abundance
# -----------------------------
sorted_cells = res_df.sort_values(by="stroma_mean", ascending=False).index.tolist()

# -----------------------------
# 3. Prepare data for plotting
# -----------------------------
plot_data = pd.melt(
    combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])], 
    id_vars=["Segment_geomx"], 
    value_vars=sorted_cells,  # use sorted order here
    var_name="Cell_Type", 
    value_name="Expression"
)

# -----------------------------
# 4. Plot boxplots
# -----------------------------
plt.figure(figsize=(12, 8))

palette = {"tsi": "#3ab7be", "stroma": "#9e82f2"}

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data, 
    palette=palette, linewidth=1.5
)

''''''
sns.stripplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data,
    dodge=True, color="black", alpha=0.5, size=3
)
''''''

# -----------------------------
# 5. Add significance stars
# -----------------------------
for i, cell in enumerate(sorted_cells):
    p = res_df.loc[cell, "p_value"]
    if p < 0.05:
        star = "*" if p >= 0.01 else "**" if p >= 0.001 else "***"
        ax.text(i, ax.get_ylim()[1]*0.95, star, color="black", ha="center", va="center", fontsize=14, fontweight="bold")

# -----------------------------
# 6. Labels and title
# -----------------------------
plt.title("Cell Abundance in Stromal Segments in Distant Stroma vs TSI", fontsize=16)
plt.xlabel("Cell Type")
plt.xticks(fontsize=12, rotation=60)
plt.ylabel("Expression Level")

# -----------------------------
# 7. Custom legends
# -----------------------------
custom_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   p < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  p < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** p < 0.001")
]
ax.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

# Legend for stroma vs TSI
handles, labels = ax.get_legend_handles_labels()
handles = [handles[0], handles[1]]  # Stroma and TSI colors
labels = ["stroma", "tsi"]
ax.legend(handles=handles, labels=labels, loc='upper left', bbox_to_anchor=(1.0, 0.85), title="Segments", title_fontsize=13, fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_13593/1946366010.py:57: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
from matplotlib.patches import Patch

# -----------------------------
# 1. Compute stats per cell type
# -----------------------------
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# -----------------------------
# 1b. FDR correction (Benjamini-Hochberg)
# -----------------------------
res_df["p_adj"] = multipletests(res_df["p_value"], method="fdr_bh")[1]

# -----------------------------
# 2. Sort cell types by stroma mean abundance
# -----------------------------
sorted_cells = res_df.sort_values(by="stroma_mean", ascending=False).index.tolist()

# -----------------------------
# 3. Prepare data for plotting
# -----------------------------
plot_data = pd.melt(
    combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])], 
    id_vars=["Segment_geomx"], 
    value_vars=sorted_cells,  # use sorted order here
    var_name="Cell_Type", 
    value_name="Expression"
)

# -----------------------------
# 4. Plot boxplots + stripplots
# -----------------------------
plt.figure(figsize=(12, 8))
palette = {"tsi": "#3ab7be", "stroma": "#9e82f2"}

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data, 
    palette=palette, linewidth=1.5, order=sorted_cells
)

sns.stripplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data,
    dodge=True, color="black", alpha=0.5, size=3, order=sorted_cells
)

# -----------------------------
# 5. Add FDR-adjusted significance stars
# -----------------------------
y_max = plot_data["Expression"].max()
for i, cell in enumerate(sorted_cells):
    p_adj = res_df.loc[cell, "p_adj"]
    if p_adj < 0.05:
        if p_adj >= 0.01:
            star = "*"
        elif p_adj >= 0.001:
            star = "**"
        else:
            star = "***"
        ax.text(i, y_max*0.95, star, color="black", ha="center", va="center", fontsize=14, fontweight="bold")

# -----------------------------
# 6. Labels and title
# -----------------------------
plt.title("Cell Abundance in Distant Stroma vs TSI (FDR-adjusted)", fontsize=16)
plt.xlabel("Cell Type")
plt.ylabel("Expression Level")
plt.xticks(fontsize=12, rotation=60)

# -----------------------------
# 7. Legends
# -----------------------------
# Segment legend
handles, labels = ax.get_legend_handles_labels()
handles = handles[:2]  # first two are stroma/tsi
labels = ["stroma", "tsi"]
ax.legend(handles=handles, labels=labels, loc='upper left', bbox_to_anchor=(1.0, 0.85),
          title="Segments", title_fontsize=13, fontsize=12, frameon=False)

# Significance legend
signif_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   FDR < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  FDR < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** FDR < 0.001"),
]
ax.add_artist(plt.legend(handles=signif_legend, loc="upper left", bbox_to_anchor=(1.0, 1.05), frameon=False))

plt.tight_layout()
plt.show()
# Out:
# /var/folders/5f/jg_zhw0n3xl1tf79w0wk705r0000gn/T/ipykernel_13593/1382775612.py:61: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.stripplot(

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
from matplotlib.patches import Patch

# =========================
# Statistical testing
# =========================

results = {}

for cell in cell_types:
    group_stroma = combined.loc[
        combined["Segment_geomx"] == "stroma", cell
    ].dropna()

    group_tsi = combined.loc[
        combined["Segment_geomx"] == "tsi", cell
    ].dropna()

    # Mann–Whitney U test (two-sided)
    stat, p_value = mannwhitneyu(
        group_stroma, group_tsi, alternative="two-sided"
    )

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# =========================
# Multiple testing correction
# =========================

res_df["p_adj"] = multipletests(
    res_df["p_value"],
    method="fdr_bh"
)[1]

# =========================
# Prepare data for plotting
# =========================

plot_data = pd.melt(
    combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])],
    id_vars=["Segment_geomx"],
    value_vars=cell_types,
    var_name="Cell_Type",
    value_name="Expression"
)

# =========================
# Plot
# =========================

plt.figure(figsize=(12, 8))



#palette = {
#    "stroma": "#65D5DF",  # cyan
#    "tsi": "#DB615C"      # red
#}


palette={"tsi": "#3ab7be", "stroma":"#9e82f2"}

ax = sns.boxplot(
    x="Cell_Type",
    y="Expression",
    hue="Segment_geomx",
    data=plot_data,
    palette=palette,
    linewidth=1.5
)

# =========================
# Add FDR-adjusted significance stars
# =========================

y_max = ax.get_ylim()[1]

for i, cell in enumerate(cell_types):
    p_adj = res_df.loc[cell, "p_adj"]

    if p_adj < 0.05:
        if p_adj >= 0.01:
            star = "*"
        elif p_adj >= 0.001:
            star = "**"
        else:
            star = "***"

        ax.text(
            i,
            y_max * 0.95,
            star,
            ha="center",
            va="center",
            fontsize=14,
            fontweight="bold",
            color="black"
        )

# =========================
# Labels and formatting
# =========================

plt.title(
    "Cell Abundance in Distant Stroma vs TSI (FDR-adjusted)",
    fontsize=16
)
plt.xlabel("Cell Type")
plt.ylabel("Expression Level")
plt.xticks(rotation=60, fontsize=12)

# =========================
# Legends
# =========================

# Segment legend
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles=handles[:2],
    labels=["stroma", "tsi"],
    title="Segments",
    title_fontsize=13,
    fontsize=12,
    loc="upper left",
    bbox_to_anchor=(1.0, 0.85),
    frameon=False
)

# Significance legend
signif_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   FDR < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  FDR < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** FDR < 0.001"),
]

ax.legend(
    handles=signif_legend,
    loc="upper left",
    bbox_to_anchor=(1.0, 1.05),
    frameon=False
)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
from matplotlib.patches import Patch

# =========================
# 1. Statistical testing per cell type
# =========================
results = {}

for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()
    
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")
    
    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value,
        "mean_total": pd.concat([group_stroma, group_tsi]).mean()
    }

res_df = pd.DataFrame(results).T

# FDR correction
res_df["p_adj"] = multipletests(res_df["p_value"], method="fdr_bh")[1]

# =========================
# 2. Sort cell types by total mean abundance
# =========================
sorted_cells = res_df.sort_values(by="mean_total", ascending=False).index.tolist()

# =========================
# 3. Prepare data for plotting
# =========================
plot_data = pd.melt(
    combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])],
    id_vars=["Segment_geomx"],
    value_vars=sorted_cells,
    var_name="Cell_Type",
    value_name="Expression"
)

# =========================
# 4. Plot
# =========================
plt.figure(figsize=(14, 8))
palette = {"stroma":"#9e82f2", "tsi": "#3ab7be"}

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", 
    data=plot_data, palette=palette, linewidth=1.5, order=sorted_cells
)


'''
sns.stripplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", 
    data=plot_data, dodge=True, color="black", alpha=0.5, size=3, order=sorted_cells
)
'''

# =========================
# 5. Add FDR-adjusted significance stars
# =========================
y_max = plot_data["Expression"].max()
for i, cell in enumerate(sorted_cells):
    p_adj = res_df.loc[cell, "p_adj"]
    if p_adj < 0.05:
        if p_adj >= 0.01:
            star = "*"
        elif p_adj >= 0.001:
            star = "**"
        else:
            star = "***"
        ax.text(i, y_max*0.95, star, ha="center", va="center", fontsize=14, fontweight="bold", color="black")

# =========================
# 6. Labels and formatting
# =========================
plt.title("Cell Abundance in Distant Stroma vs TSI (FDR-adjusted)", fontsize=16, fontweight="bold")
plt.xlabel("Cell Type")
plt.ylabel("Expression Level")
plt.xticks(rotation=60, fontsize=12)

# =========================
# 7. Legends
# =========================
# Segment legend
handles, labels = ax.get_legend_handles_labels()
handles = handles[:2]  # first two are stroma/tsi
labels = ["stroma", "tsi"]
ax.legend(handles=handles, labels=labels, title="Segments", title_fontsize=13, fontsize=12,
          loc="upper left", bbox_to_anchor=(1.0, 0.85), frameon=False)

# Significance legend
signif_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   FDR < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  FDR < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** FDR < 0.001"),
]
ax.add_artist(plt.legend(handles=signif_legend, loc="upper left", bbox_to_anchor=(1.0, 1.05), frameon=False))

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
from matplotlib.patches import Patch

# =========================
# 1. Statistical testing per cell type
# =========================
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()
    
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")
    
    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value,
        "mean_total": pd.concat([group_stroma, group_tsi]).mean()
    }

res_df = pd.DataFrame(results).T

# FDR correction
res_df["p_adj"] = multipletests(res_df["p_value"], method="fdr_bh")[1]

# =========================
# 2. Sort cell types by total mean abundance
# =========================
sorted_cells = res_df.sort_values(by="mean_total", ascending=False).index.tolist()

# =========================
# 3. Prepare data for plotting
# =========================
plot_data = pd.melt(
    combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])],
    id_vars=["Segment_geomx"],
    value_vars=sorted_cells,
    var_name="Cell_Type",
    value_name="Expression"
)

# =========================
# 4. Plot
# =========================
plt.figure(figsize=(14, 8))
palette = {"stroma":"#6276bc", "tsi": "#f07833"}

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", 
    data=plot_data, palette=palette, linewidth=1.5, order=sorted_cells
)

# =========================
# 5. Add FDR-adjusted significance stars
# =========================
y_max = plot_data["Expression"].max()
for i, cell in enumerate(sorted_cells):
    p_adj = res_df.loc[cell, "p_adj"]
    if p_adj < 0.05:
        if p_adj >= 0.01:
            star = "*"
        elif p_adj >= 0.001:
            star = "**"
        else:
            star = "***"
        ax.text(i, y_max*0.95, star, ha="center", va="center", fontsize=14, fontweight="bold", color="black")

# =========================
# 6. Labels and formatting
# =========================
plt.title("Cell Abundance in Distant Stroma vs TSI (FDR-adjusted)", fontsize=16, fontweight="bold")
plt.xlabel("Cell Type")
plt.ylabel("Expression Level")
plt.xticks(rotation=60, fontsize=12)

# =========================
# 7. Legends
# =========================
# Segment legend (stroma vs TSI)
handles, labels = ax.get_legend_handles_labels()
segment_handles = handles[:2]  # first two are stroma/tsi
segment_labels = ["stroma", "tsi"]
legend1 = ax.legend(handles=segment_handles, labels=segment_labels,
                    title="Segments", title_fontsize=13, fontsize=12,
                    loc='upper left', bbox_to_anchor=(1.0, 0.85), frameon=False)

# Add significance legend (FDR stars) without removing segment legend
'''
signif_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   FDR < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  FDR < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** FDR < 0.001"),
]
ax.add_artist(legend1)  # keep first legend
ax.add_artist(plt.legend(handles=signif_legend, loc="upper left", bbox_to_anchor=(1.0, 1.05), frameon=False))
'''

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from matplotlib.patches import Patch

# Store results
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# Create a DataFrame for plotting
plot_data = pd.melt(combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])], 
                    id_vars=["Segment_geomx"], 
                    value_vars=cell_types, 
                    var_name="Cell_Type", 
                    value_name="Expression")

# Define custom colors for stroma and TSI
#palette = {"tsi": "#65D5DF", "stroma": "#DB615C"}  # Green for stroma, tomato red for TSI
palette={"tsi": "#f07833", "stroma":"#6276bc"}
# Plot boxplots
plt.figure(figsize=(12, 8))

# Create the boxplot
ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data, 
    palette=palette, linewidth=1.5
)

# Add significance stars
for i, cell in enumerate(cell_types):
    p = res_df.loc[cell, "p_value"]
    if p < 0.05:
        # Place star above the boxplot (adjust the position slightly)
        ax.text(i, ax.get_ylim()[1] * 0.95, "*" if p>=0.01 else "**" if p>=0.001 else "***",
                color="black", ha="center", va="center", fontsize=14, fontweight="bold")

# Labels and title
plt.title("Cell Abundance in Stroma AOIs in Distant Stroma vs TSI", fontsize=16,fontweight="bold")
plt.xlabel("Cell Type")
plt.xticks(fontsize=12, rotation=60)
plt.ylabel("Expression Level")

# Create custom legend for significance
'''
custom_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   p < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  p < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** p < 0.001")
]
'''
# =========================
# Legends
# =========================

# Segment (Geomx) legend
handles, labels = ax.get_legend_handles_labels()
segment_legend = ax.legend(
    handles=handles[:2],
    labels=["stroma", "tsi"],
    title="Geomx Segment",
    title_fontsize=13,
    fontsize=12,
    loc="upper left",
    bbox_to_anchor=(1.05, 0.85),
    frameon=False
)

# Add the first legend back explicitly
ax.add_artist(segment_legend)

# Significance legend
signif_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   FDR < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  FDR < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** FDR < 0.001"),
]

ax.legend(
    handles=signif_legend,
    title="Significance",
    title_fontsize=13,
    fontsize=12,
    loc="upper left",
    bbox_to_anchor=(1.0, 1.05),
    frameon=False
)


# Add legend for the significance stars
#ax.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

# Adjust the legend for stroma and tsi (automatically created by hue)
#handles, labels = ax.get_legend_handles_labels()
# Set the correct colors for the Segment_geomx in the legend
#handles = [Patch(facecolor="#8FBC8F", label="Stroma"), Patch(facecolor="#FF6347", label="TSI")]

# Add the custom color legend for stroma and tsi
#ax.legend(handles=handles, loc='upper left', bbox_to_anchor=(1.0, 0.85), title="Segments", title_fontsize=13, fontsize=12)

# Tight layout to ensure everything fits
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from matplotlib.patches import Patch

# Store results
results = {}
for cell in cell_types:
    group_stroma = combined.loc[combined["Segment_geomx"] == "stroma", cell].dropna()
    group_tsi    = combined.loc[combined["Segment_geomx"] == "tsi", cell].dropna()

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(group_stroma, group_tsi, alternative="two-sided")

    results[cell] = {
        "stroma_mean": group_stroma.mean(),
        "tsi_mean": group_tsi.mean(),
        "p_value": p_value
    }

# Convert to DataFrame
res_df = pd.DataFrame(results).T

# Create a DataFrame for plotting
plot_data = pd.melt(combined.loc[combined["Segment_geomx"].isin(["stroma", "tsi"])], 
                    id_vars=["Segment_geomx"], 
                    value_vars=cell_types, 
                    var_name="Cell_Type", 
                    value_name="Expression")

# Plot boxplots
plt.figure(figsize=(12, 6))

ax = sns.boxplot(
    x="Cell_Type", y="Expression", hue="Segment_geomx", data=plot_data, 
    palette=["lightblue", "salmon"], linewidth=1.5
)

# Add significance stars and combine with segment labels
for i, cell in enumerate(cell_types):
    p = res_df.loc[cell, "p_value"]
    
    # Determine the star based on p-value
    star = "*" if p >= 0.01 else "**" if p >= 0.001 else "***" if p < 0.001 else ""
    
    if star:  # Only add stars if p < 0.05
        # Place star with segment name above the boxplot (adjust the position slightly)
        ax.text(i, ax.get_ylim()[1] * 0.95, f"{labels[i]} {star}",
                color="black", ha="center", va="center", fontsize=14, fontweight="bold")

# Labels and title
plt.title("Cell Type Abundance in Stromal Segments in Distant Stroma vs TSI")
plt.xlabel("Cell Type")
plt.xticks(fontsize=10, rotation=45)
plt.ylabel("Expression Level")

# Create custom legend for significance
custom_legend = [
    Patch(facecolor="none", edgecolor="none", label="*   p < 0.05"),
    Patch(facecolor="none", edgecolor="none", label="**  p < 0.01"),
    Patch(facecolor="none", edgecolor="none", label="*** p < 0.001")
]

# Add legend for the significance stars
ax.legend(handles=custom_legend, loc='upper left', bbox_to_anchor=(1.05, 1), frameon=False)

# Adjust the legend for stroma and tsi (automatically created by hue)
handles, labels = ax.get_legend_handles_labels()
# Remove the 'hue' legend entry for the 'Cell_Type' (because it is already handled in the plot)
handles = [handles[0], handles[1]]  # Stroma and TSI colors
labels = ["Stroma", "TSI"]

# Add the custom color legend
ax.legend(handles=handles, labels=labels, loc='upper left', bbox_to_anchor=(1.05, 0.75), title="Segments")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 50
#      46     star = "*" if p >= 0.01 else "**" if p >= 0.001 else "***" if p < 0.001 else ""
#      48     if star:  # Only add stars if p < 0.05
#      49         # Place star with segment name above the boxplot (adjust the position slightly)
# ---> 50         ax.text(i, ax.get_ylim()[1] * 0.95, f"{labels[i]} {star}",
#      51                 color="black", ha="center", va="center", fontsize=14, fontweight="bold")
#      53 # Labels and title
#      54 plt.title("Cell Type Abundance in Stromal Segments in Distant Stroma vs TSI")
#
# IndexError: list index out of range
