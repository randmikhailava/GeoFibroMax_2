# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr, wilcoxon
import plotly.express as px
import plotly.graph_objects as go
import nbformat

from scipy.stats import ttest_ind, f_oneway
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib_venn import venn2
import os
import scipy.cluster.hierarchy as sch
from scipy.stats import ttest_rel, wilcoxon
from statsmodels.stats.multitest import multipletests

# %%
target_CAFs=["FAP", "PDGFRA", "PDGFRB", "S100A4", "LRRC15", "IL1R1", "IL1R2","SMO"]
target_receptors_molecules=["TGFB1","TGFB2","TGFB3", "TGFBR1","TGFBR2","TGFBR3","IL6", "IL6R", "IL10RA","IL10RB", "CXCL8", "CXCL12", 
 "CCR5", "CXCR2", "CXCR1", "CXCR4", "CXCL10","CXCL9","HGF", "MET", "FGF1","FGF2","FGF7","FGF10", "FGFR1","FGFR2","FGFR3","FGFR4","IL11","HAS1","HAS2","HYAL1","HYAL2"]

# %% [markdown]
# ## Loading the GeoMx data for batch 1 and 2

# %%
fibr_gene_expression_modified=pd.read_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged/filtered_fibroblasts_gene_exp_transposed_w_clinical.csv")
clinical_data=pd.read_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged/9_eyemt_patient_clinical_data_new.csv")
fibr_gene_expression_modified["Patient"]=fibr_gene_expression_modified["Sample"].str.extract(r'(S\d+)')
fibr_gene_expression_modified=fibr_gene_expression_modified.merge(clinical_data[["Patient","PFS_quartile_b12"]],on="Patient", how="left")
fibr_gene_expression_modified=fibr_gene_expression_modified.merge(clinical_data[["Patient","OS_quartile_b12"]],on="Patient", how="left")

# %%
len(fibr_gene_expression_modified)
# Out:
# 2259

# %%
fibr_gene_expression_modified["PFS_HL_group"] = fibr_gene_expression_modified["PFS_quartile_b12"].apply(
    lambda x: "Low" if x in [1, "1", 2, "2"] else ("High" if x in [3, "3", 4, "4"] else None)
)
fibr_gene_expression_modified["OS_HL_group"] = fibr_gene_expression_modified["OS_quartile_b12"].apply(
    lambda x: "Low" if x in [1, "1", 2, "2"] else ("High" if x in [3, "3", 4, "4"] else None)
)

# %%
fibr_gene_expression_modified=fibr_gene_expression_modified.drop_duplicates()
fibr_gene_expression_modified
# Out:
#                      dcc_filename    SAMD11     NOC2L    KLHL17   PLEKHN1  \
# 0     DSP-1001660016604-A-A02.dcc  1.718431  2.137428  1.836881  1.997698
# 1     DSP-1001660016604-A-A04.dcc  1.622100  2.027326  1.737519  1.901971
# 2     DSP-1001660016604-A-A05.dcc  1.427961  1.505719  1.830641  1.348903
# 3     DSP-1001660016604-A-A07.dcc  1.353614  1.787912  1.868598  1.631783
# 4     DSP-1001660016604-A-A08.dcc  1.829375  1.602863  1.291572  1.448092
# ...                           ...       ...       ...       ...       ...
# 2239  DSP-1001660037247-C-D01.dcc  1.808434  1.844244  1.772121  1.524628
# 2243  DSP-1001660037247-C-D02.dcc  1.399579  1.726509  1.367213  1.114765
# 2247  DSP-1001660037247-C-D03.dcc  0.084584  0.164450 -0.030218 -0.168501
# 2251  DSP-1001660037247-C-D04.dcc  1.367126  1.920226  1.332952 -0.329163
# 2255  DSP-1001660037247-C-D06.dcc  1.457564  1.492254  1.423708 -0.329576
#
#          PERM1      HES4     ISG15      AGRN    RNF223  ...  PFS_quartile  \
# 0     0.161226  2.480789  4.364810  2.270061  0.033787  ...             1
# 1     0.158211  2.375319  5.534481  2.163770  0.033655  ...             1
# 2     0.165076  2.201253  5.497989  2.271254  0.033957  ...             1
# 3     0.164922  2.126467  6.245903  2.308907  0.033950  ...             1
# 4     0.164608  1.941802  3.836590  1.731314  0.033936  ...             1
# ...        ...       ...       ...       ...       ...  ...           ...
# 2239 -0.121914  1.967129  3.434814  2.026795  0.028477  ...             3
# 2243  0.917727  2.449179  6.042179  2.140981  0.028518  ...             3
# 2247 -0.042646  0.429389  7.393944  0.414974  0.028022  ...             3
# 2251 -0.123800  2.040032  4.567637  2.101017  0.028499  ...             3
# 2255 -0.124077  2.155458  3.858275  1.672784  0.028502  ...             3
#
#       OS_quartile  BRCA_status  HRP_status  Segment  Patient  \
# 0               1          0.0         1.0   stroma     S130
# 1               1          0.0         1.0   stroma     S130
# 2               1          0.0         1.0    tumor     S130
# 3               1          0.0         1.0    tumor     S130
# 4               1          0.0         1.0   stroma     S130
# ...           ...          ...         ...      ...      ...
# 2239            1          0.0         1.0   stroma     S333
# 2243            1          0.0         1.0   stroma     S333
# 2247            1          0.0         1.0    tumor     S333
# 2251            1          0.0         1.0   stroma     S333
# 2255            1          0.0         1.0   stroma     S333
#
#       PFS_quartile_b12  OS_quartile_b12  PFS_HL_group  OS_HL_group
# 0                  2.0              1.0           Low          Low
# 1                  2.0              1.0           Low          Low
# 2                  2.0              1.0           Low          Low
# 3                  2.0              1.0           Low          Low
# 4                  2.0              1.0           Low          Low
# ...                ...              ...           ...          ...
# 2239               4.0              2.0          High          Low
# 2243               4.0              2.0          High          Low
# 2247               4.0              2.0          High          Low
# 2251               4.0              2.0          High          Low
# 2255               4.0              2.0          High          Low
#
# [423 rows x 14659 columns]

# %% [markdown]
# ## Checking the target gene expression per sample, in stroma segment per PFS and OS

# %%
sample_metadata= fibr_gene_expression_modified[["Sample", "PFS_HL_group", "OS_HL_group"]].drop_duplicates().set_index("Sample")
stroma_gene_expression=fibr_gene_expression_modified[fibr_gene_expression_modified['Segment']=='stroma']

average_stroma_gene_expression=stroma_gene_expression.groupby('Sample')[target_CAFs+target_receptors_molecules].mean()
average_stroma_gene_expression = average_stroma_gene_expression.join(sample_metadata)
average_stroma_gene_expression.head(5)
# Out:
#                 FAP    PDGFRA    PDGFRB    S100A4    LRRC15     IL1R1  \
# Sample
# S015_post  4.563758  4.715512  4.218255  2.948434  4.345709  3.478865
# S015_pre   4.930071  4.369112  4.111848  2.661163  3.691044  4.197306
# S027_post  4.678211  5.097098  5.064894  3.205728  3.753150  4.039051
# S027_pre   4.370046  4.000786  3.428843  2.659461  4.408627  3.302794
# S032_post  4.534982  4.284750  3.835740  2.792009  4.585143  3.911578
#
#               IL1R2       SMO     TGFB1     TGFB2  ...     FGFR2     FGFR3  \
# Sample                                             ...
# S015_post  1.318255  1.416192  2.687415  2.575284  ...  1.399364  0.604686
# S015_pre   1.772768  1.657419  2.687384  3.048880  ...  1.891527  1.095567
# S027_post  1.505599  1.699002  2.283074  2.546047  ...  0.863825  0.429573
# S027_pre   1.229415  1.300093  2.388567  2.520256  ...  1.618187  0.753126
# S032_post  1.311714  1.391109  2.352568  2.126993  ...  1.513402  0.751687
#
#               FGFR4      IL11      HAS1      HAS2     HYAL1     HYAL2  \
# Sample
# S015_post  0.812162  2.367929  2.995947  2.717272  1.784699  2.292120
# S015_pre   1.292330  2.875106  3.531457  3.050977  2.050613  2.584450
# S027_post  1.807855  3.000496  3.663743  3.179359  2.070098  2.560837
# S027_pre  -0.026285  2.080156  2.696289  2.285164  1.661174  2.656956
# S032_post  0.304241  2.280565  2.998480  2.502677  1.844294  2.313490
#
#            PFS_HL_group  OS_HL_group
# Sample
# S015_post          High         High
# S015_pre           High         High
# S027_post          High         High
# S027_pre           High         High
# S032_post          High         High
#
# [5 rows x 43 columns]

# %%
for gene in target_CAFs:
    plt.figure(figsize=(7, 4))
    sns.boxplot(x="PFS_HL_group",y=gene,data=average_stroma_gene_expression, color='lightblue', order=["Low", "High"])
    sns.stripplot(x="PFS_HL_group", y=gene, data=average_stroma_gene_expression, color='grey', alpha=0.6, jitter=True, order=["Low", "High"])
    plt.title(f"{gene} expression in fibroblasts in stroma segment by PFS")
    plt.xlabel("PFS Quartile")
    plt.ylabel("Gene Expression Level")
    plt.show()

# %%
for gene in target_receptors_molecules:
    plt.figure(figsize=(7, 4))
    sns.boxplot(x="PFS_HL_group",y=gene,data=average_stroma_gene_expression, color='lightgreen',order=["Low", "High"])
    sns.stripplot(x="PFS_HL_group", y=gene, data=average_stroma_gene_expression, color='grey', alpha=0.4, jitter=True, order=["Low", "High"])
    plt.title(f"{gene} expression in fibroblasts in stroma segment by PFS per sample")
    plt.xlabel("PFS group")
    plt.ylabel("Mean Gene Expression Level")
    plt.show()

# %%
for gene in target_CAFs:
    plt.figure(figsize=(7, 4))
    sns.boxplot(x="OS_HL_group",y=gene,data=average_stroma_gene_expression, color='red', order=["Low", "High"])
    sns.stripplot(x="OS_HL_group", y=gene, data=average_stroma_gene_expression, color='grey', alpha=0.6, jitter=True, order=["Low", "High"])
    plt.title(f"{gene} expression in fibroblasts in stroma segment by OS per sample")
    plt.xlabel("OS Quartile")
    plt.ylabel("Mean Gene Expression Level")
    plt.show()

# %%
for gene in  target_receptors_molecules:
    plt.figure(figsize=(7, 4))
    sns.boxplot(x="OS_HL_group",y=gene,data=average_stroma_gene_expression, color='violet', order=["Low", "High"])
    sns.stripplot(x="OS_HL_group", y=gene, data=average_stroma_gene_expression, color='grey', alpha=0.6, jitter=True, order=["Low", "High"])
    plt.title(f"{gene} expression in fibroblasts in stroma segment by OS per sample")
    plt.xlabel("OS Quartile")
    plt.ylabel("Mean Gene Expression Level")
    plt.show()
