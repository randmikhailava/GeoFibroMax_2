# %%
import pandas as pd
import numpy as np
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.colors as mcolors
import statsmodels.api as sm
from tqdm import tqdm

# %%
clinical_data=pd.read_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged/9_eyemt_patient_clinical_data_new.csv")

# %%
fibr_gene_expression_modified=pd.read_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged_new/fibroblasts_gene_expression_data_new_batch_three_merged_transposed.csv")
cell_proportions=pd.read_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged_new/bp_res_mid_lvl_ct_updated_ct_fraction_batch_3.csv")
fibr_gene_expression_modified = pd.merge(
    fibr_gene_expression_modified,
    cell_proportions,
    on="dcc_filename",
    how="inner"  # or "left", "right", "outer" depending on your needs
)
fibr_gene_expression_modified["Patient"]=fibr_gene_expression_modified["Sample"].str.extract(r'(S\d+)')
fibr_gene_expression_modified=fibr_gene_expression_modified.merge(clinical_data[["Patient","PFS_quartile_b123","OS_quartile_b123","Sample"]],on="Patient", how="left")
fibr_gene_expression_modified.drop_duplicates(subset=["dcc_filename"], inplace=True)

# %%
fibr_gene_expression_modified=fibr_gene_expression_modified[fibr_gene_expression_modified["Segment"] == "stroma"]

# %%
fibr_gene_expression_modified["Segment_geomx"].to_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged_new/segment_geomx_fibr_expression_pre_post.csv", index=False)

# %%
geomx_data_columns=pd.read_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged_new/fibroblasts_gene_expression_data_new_batch_three_merged_transposed.csv").columns
geomx_data_columns_list=geomx_data_columns.tolist()

# %%
geomx_data_colunms_list=geomx_data_columns_list[1:]
len(geomx_data_colunms_list)
# Out:
# 14920

# %%
columns_to_select = list(set(geomx_data_columns).intersection(fibr_gene_expression_modified.columns))
geomx_data_w_metadata_only = fibr_gene_expression_modified[['dcc_filename']+columns_to_select]

# %%
geomx_data_w_metadata_only.head(5)
# Out:
#                   dcc_filename    KLHL42     USP24      QDPR     RFESD  \
# 0  DSP-1001660016604-A-A02.dcc -0.337138  2.153997  1.719573 -0.438774
# 1  DSP-1001660016604-A-A04.dcc -0.337114 -0.325901  1.555881 -0.438716
# 3  DSP-1001660016604-A-A06.dcc  1.668845  1.680060  2.526595  1.567219
# 5  DSP-1001660016604-A-A08.dcc  1.554319  1.565534  2.371073  1.452664
# 8  DSP-1001660016604-A-B02.dcc  1.559261  1.570476  2.377800  1.457598
#
#       SENP5      FEN1    NDUFA4      IDH1     SH2B1  ...    ZNF442     AADAC  \
# 0 -0.247221  2.682568  2.323078 -0.110843  1.935960  ...  1.722202  3.246953
# 1 -0.247224  1.657390  2.159144 -0.110886  1.772160  ...  1.558455  3.038925
# 3  1.758754  2.111450  1.849126 -0.110855  1.462047  ...  1.248304  2.932588
# 5  1.644249  2.472584  2.471540  1.780649  1.347455  ...  1.133669  3.429308
# 8 -0.247219  2.479311  1.739598  1.785606  1.352378  ...  1.876686  3.436764
#
#        TSKS     ITGA1    ANKZF1   TMEM201    DEFB4B     MARK3       ADM  \
# 0 -0.423753  3.095333 -0.273508 -0.387659 -0.292084  2.077742  3.125477
# 1 -0.423701  3.291354 -0.273509  1.928398 -0.292084  2.745299  3.322051
# 3 -0.423738  2.875706 -0.273508  1.618329 -0.292084  2.368143  2.906011
# 5  1.467688  3.020267 -0.273507 -0.387681 -0.292084  2.729179  3.521817
# 8  1.472623  3.857941 -0.273507  1.508726 -0.292084  2.232093  3.311672
#
#      DDX39B
# 0  2.235113
# 1  2.071101
# 3  1.761138
# 5  2.383616
# 8  1.651691
#
# [5 rows x 14922 columns]

# %%
geomx_data_w_metadata_only_T = geomx_data_w_metadata_only.set_index("dcc_filename").T
geomx_data_w_metadata_only_T
# Out:
# dcc_filename  (DSP-1001660016604-A-A02.dcc, DSP-1001660016604-A-A02.dcc)  \
# KLHL42                                                -0.337138
# USP24                                                  2.153997
# QDPR                                                   1.719573
# RFESD                                                 -0.438774
# SENP5                                                 -0.247221
# ...                                                         ...
# TMEM201                                               -0.387659
# DEFB4B                                                -0.292084
# MARK3                                                  2.077742
# ADM                                                    3.125477
# DDX39B                                                 2.235113
#
# dcc_filename  (DSP-1001660016604-A-A04.dcc, DSP-1001660016604-A-A04.dcc)  \
# KLHL42                                                -0.337114
# USP24                                                 -0.325901
# QDPR                                                   1.555881
# RFESD                                                 -0.438716
# SENP5                                                 -0.247224
# ...                                                         ...
# TMEM201                                                1.928398
# DEFB4B                                                -0.292084
# MARK3                                                  2.745299
# ADM                                                    3.322051
# DDX39B                                                 2.071101
#
# dcc_filename  (DSP-1001660016604-A-A06.dcc, DSP-1001660016604-A-A06.dcc)  \
# KLHL42                                                 1.668845
# USP24                                                  1.680060
# QDPR                                                   2.526595
# RFESD                                                  1.567219
# SENP5                                                  1.758754
# ...                                                         ...
# TMEM201                                                1.618329
# DEFB4B                                                -0.292084
# MARK3                                                  2.368143
# ADM                                                    2.906011
# DDX39B                                                 1.761138
#
# dcc_filename  (DSP-1001660016604-A-A08.dcc, DSP-1001660016604-A-A08.dcc)  \
# KLHL42                                                 1.554319
# USP24                                                  1.565534
# QDPR                                                   2.371073
# RFESD                                                  1.452664
# SENP5                                                  1.644249
# ...                                                         ...
# TMEM201                                               -0.387681
# DEFB4B                                                -0.292084
# MARK3                                                  2.729179
# ADM                                                    3.521817
# DDX39B                                                 2.383616
#
# dcc_filename  (DSP-1001660016604-A-B02.dcc, DSP-1001660016604-A-B02.dcc)  \
# KLHL42                                                 1.559261
# USP24                                                  1.570476
# QDPR                                                   2.377800
# RFESD                                                  1.457598
# SENP5                                                 -0.247219
# ...                                                         ...
# TMEM201                                                1.508726
# DEFB4B                                                -0.292084
# MARK3                                                  2.232093
# ADM                                                    3.311672
# DDX39B                                                 1.651691
#
# dcc_filename  (DSP-1001660016604-A-B06.dcc, DSP-1001660016604-A-B06.dcc)  \
# KLHL42                                                 1.802997
# USP24                                                 -0.325937
# QDPR                                                   2.174256
# RFESD                                                  1.701339
# SENP5                                                  1.892930
# ...                                                         ...
# TMEM201                                                1.752464
# DEFB4B                                                -0.292084
# MARK3                                                  2.532351
# ADM                                                    3.401612
# DDX39B                                                 1.895409
#
# dcc_filename  (DSP-1001660016604-A-B08.dcc, DSP-1001660016604-A-B08.dcc)  \
# KLHL42                                                -0.337081
# USP24                                                 -0.325869
# QDPR                                                   2.119520
# RFESD                                                 -0.438632
# SENP5                                                 -0.247228
# ...                                                         ...
# TMEM201                                               -0.387558
# DEFB4B                                                -0.292084
# MARK3                                                  2.477979
# ADM                                                    3.029340
# DDX39B                                                 2.634280
#
# dcc_filename  (DSP-1001660016604-A-B10.dcc, DSP-1001660016604-A-B10.dcc)  \
# KLHL42                                                 1.672625
# USP24                                                  1.683840
# QDPR                                                   2.014469
# RFESD                                                 -0.438799
# SENP5                                                 -0.247220
# ...                                                         ...
# TMEM201                                                1.622096
# DEFB4B                                                -0.292084
# MARK3                                                  2.889658
# ADM                                                    2.910955
# DDX39B                                                 2.530147
#
# dcc_filename  (DSP-1001660016604-A-B12.dcc, DSP-1001660016604-A-B12.dcc)  \
# KLHL42                                                 1.640225
# USP24                                                 -0.325920
# QDPR                                                   1.974573
# RFESD                                                  1.538593
# SENP5                                                  1.730138
# ...                                                         ...
# TMEM201                                                1.589706
# DEFB4B                                                -0.292084
# MARK3                                                  2.846212
# ADM                                                    2.865945
# DDX39B                                                 2.490071
#
# dcc_filename  (DSP-1001660016604-A-C02.dcc, DSP-1001660016604-A-C02.dcc)  ...  \
# KLHL42                                                 1.164196           ...
# USP24                                                  1.175412           ...
# QDPR                                                   1.818878           ...
# RFESD                                                  1.062540           ...
# SENP5                                                  1.254129           ...
# ...                                                         ...           ...
# TMEM201                                                1.113665           ...
# DEFB4B                                                -0.292084           ...
# MARK3                                                  2.176977           ...
# ADM                                                    2.687237           ...
# DDX39B                                                 2.334605           ...
#
# dcc_filename  (DSP-1001660039918-D-G11.dcc, DSP-1001660039918-D-G11.dcc)  \
# KLHL42                                                 0.764414
# USP24                                                  0.764974
# QDPR                                                   1.297505
# RFESD                                                  0.918930
# SENP5                                                 -0.296274
# ...                                                         ...
# TMEM201                                                0.815203
# DEFB4B                                                -0.292084
# MARK3                                                  1.964154
# ADM                                                    2.377565
# DDX39B                                                 2.129814
#
# dcc_filename  (DSP-1001660039918-D-G12.dcc, DSP-1001660039918-D-G12.dcc)  \
# KLHL42                                                 0.424460
# USP24                                                  0.425023
# QDPR                                                   0.841663
# RFESD                                                  0.578924
# SENP5                                                  0.682312
# ...                                                         ...
# TMEM201                                                0.475224
# DEFB4B                                                -0.292084
# MARK3                                                  1.943141
# ADM                                                    1.527460
# DDX39B                                                 2.490829
#
# dcc_filename  (DSP-1001660039918-D-H02.dcc, DSP-1001660039918-D-H02.dcc)  \
# KLHL42                                                 1.028397
# USP24                                                  1.028954
# QDPR                                                   1.640071
# RFESD                                                  1.182964
# SENP5                                                  1.286454
# ...                                                         ...
# TMEM201                                                1.079210
# DEFB4B                                                -0.292084
# MARK3                                                  1.894839
# ADM                                                    2.818576
# DDX39B                                                 2.518660
#
# dcc_filename  (DSP-1001660039918-D-H03.dcc, DSP-1001660039918-D-H03.dcc)  \
# KLHL42                                                 1.106481
# USP24                                                  0.587594
# QDPR                                                   1.438831
# RFESD                                                  0.741623
# SENP5                                                  0.845129
# ...                                                         ...
# TMEM201                                                0.637860
# DEFB4B                                                -0.292084
# MARK3                                                  1.693706
# ADM                                                    2.801190
# DDX39B                                                 2.159764
#
# dcc_filename  (DSP-1001660039918-D-H04.dcc, DSP-1001660039918-D-H04.dcc)  \
# KLHL42                                                 0.755932
# USP24                                                  0.490417
# QDPR                                                   1.572116
# RFESD                                                  0.644450
# SENP5                                                  0.747961
# ...                                                         ...
# TMEM201                                                1.026229
# DEFB4B                                                -0.292084
# MARK3                                                  2.067725
# ADM                                                    1.991405
# DDX39B                                                 2.117222
#
# dcc_filename  (DSP-1001660039918-D-H06.dcc, DSP-1001660039918-D-H06.dcc)  \
# KLHL42                                                 1.032508
# USP24                                                  0.532621
# QDPR                                                   1.891291
# RFESD                                                  0.686660
# SENP5                                                  0.790176
# ...                                                         ...
# TMEM201                                                1.083333
# DEFB4B                                                -0.292084
# MARK3                                                  2.359441
# ADM                                                    2.685699
# DDX39B                                                 2.311433
#
# dcc_filename  (DSP-1001660039918-D-H07.dcc, DSP-1001660039918-D-H07.dcc)  \
# KLHL42                                                 0.861244
# USP24                                                  0.861798
# QDPR                                                   1.654195
# RFESD                                                  1.015844
# SENP5                                                  0.664157
# ...                                                         ...
# TMEM201                                                0.912073
# DEFB4B                                                -0.292084
# MARK3                                                  2.109367
# ADM                                                    2.543386
# DDX39B                                                 2.074339
#
# dcc_filename  (DSP-1001660039918-D-H09.dcc, DSP-1001660039918-D-H09.dcc)  \
# KLHL42                                                 1.053487
# USP24                                                  0.317909
# QDPR                                                   1.264687
# RFESD                                                  0.471948
# SENP5                                                  0.575465
# ...                                                         ...
# TMEM201                                                0.790239
# DEFB4B                                                -0.292084
# MARK3                                                  1.927115
# ADM                                                    2.065415
# DDX39B                                                 2.261720
#
# dcc_filename  (DSP-1001660039918-D-H11.dcc, DSP-1001660039918-D-H11.dcc)  \
# KLHL42                                                 0.494380
# USP24                                                  0.494936
# QDPR                                                   1.293574
# RFESD                                                  0.648954
# SENP5                                                  1.019427
# ...                                                         ...
# TMEM201                                                0.812173
# DEFB4B                                                -0.292084
# MARK3                                                  2.285526
# ADM                                                    2.372409
# DDX39B                                                 2.241361
#
# dcc_filename  (DSP-1001660039918-D-H12.dcc, DSP-1001660039918-D-H12.dcc)
# KLHL42                                                 0.596216
# USP24                                                  0.596773
# QDPR                                                   1.453029
# RFESD                                                  0.368548
# SENP5                                                  0.472034
# ...                                                         ...
# TMEM201                                                0.647027
# DEFB4B                                                -0.292084
# MARK3                                                  1.866218
# ADM                                                    2.192627
# DDX39B                                                 2.175323
#
# [14920 rows x 705 columns]

# %%
geomx_data_w_metadata_only_T["DESCRIPTION"] = np.nan

# Step 3: Reorder columns so 'DESCRIPTION' is the second one
cols = geomx_data_w_metadata_only_T.columns.tolist()
# Move 'DESCRIPTION' to position 1 (after 'NAME')
cols = [cols[0]] + ['DESCRIPTION'] + cols[1:-1]  # -1 to remove the old 'DESCRIPTION' at the end
geomx_data_w_metadata_only_T = geomx_data_w_metadata_only_T[cols]

# Step 4: Reset index (if needed) to ensure clean RangeIndex
#geomx_data_w_metadata_only_T.reset_index(drop=True, inplace=True)
#geomx_data_w_metadata_only_T
geomx_data_w_metadata_only_T.head(5)
# Out:
# dcc_filename  (DSP-1001660016604-A-A02.dcc, DSP-1001660016604-A-A02.dcc)  \
# KLHL42                                                -0.337138
# USP24                                                  2.153997
# QDPR                                                   1.719573
# RFESD                                                 -0.438774
# SENP5                                                 -0.247221
#
# dcc_filename  DESCRIPTION  \
# KLHL42                NaN
# USP24                 NaN
# QDPR                  NaN
# RFESD                 NaN
# SENP5                 NaN
#
# dcc_filename  (DSP-1001660016604-A-A04.dcc, DSP-1001660016604-A-A04.dcc)  \
# KLHL42                                                -0.337114
# USP24                                                 -0.325901
# QDPR                                                   1.555881
# RFESD                                                 -0.438716
# SENP5                                                 -0.247224
#
# dcc_filename  (DSP-1001660016604-A-A06.dcc, DSP-1001660016604-A-A06.dcc)  \
# KLHL42                                                 1.668845
# USP24                                                  1.680060
# QDPR                                                   2.526595
# RFESD                                                  1.567219
# SENP5                                                  1.758754
#
# dcc_filename  (DSP-1001660016604-A-A08.dcc, DSP-1001660016604-A-A08.dcc)  \
# KLHL42                                                 1.554319
# USP24                                                  1.565534
# QDPR                                                   2.371073
# RFESD                                                  1.452664
# SENP5                                                  1.644249
#
# dcc_filename  (DSP-1001660016604-A-B02.dcc, DSP-1001660016604-A-B02.dcc)  \
# KLHL42                                                 1.559261
# USP24                                                  1.570476
# QDPR                                                   2.377800
# RFESD                                                  1.457598
# SENP5                                                 -0.247219
#
# dcc_filename  (DSP-1001660016604-A-B06.dcc, DSP-1001660016604-A-B06.dcc)  \
# KLHL42                                                 1.802997
# USP24                                                 -0.325937
# QDPR                                                   2.174256
# RFESD                                                  1.701339
# SENP5                                                  1.892930
#
# dcc_filename  (DSP-1001660016604-A-B08.dcc, DSP-1001660016604-A-B08.dcc)  \
# KLHL42                                                -0.337081
# USP24                                                 -0.325869
# QDPR                                                   2.119520
# RFESD                                                 -0.438632
# SENP5                                                 -0.247228
#
# dcc_filename  (DSP-1001660016604-A-B10.dcc, DSP-1001660016604-A-B10.dcc)  \
# KLHL42                                                 1.672625
# USP24                                                  1.683840
# QDPR                                                   2.014469
# RFESD                                                 -0.438799
# SENP5                                                 -0.247220
#
# dcc_filename  (DSP-1001660016604-A-B12.dcc, DSP-1001660016604-A-B12.dcc)  ...  \
# KLHL42                                                 1.640225           ...
# USP24                                                 -0.325920           ...
# QDPR                                                   1.974573           ...
# RFESD                                                  1.538593           ...
# SENP5                                                  1.730138           ...
#
# dcc_filename  (DSP-1001660039918-D-G11.dcc, DSP-1001660039918-D-G11.dcc)  \
# KLHL42                                                 0.764414
# USP24                                                  0.764974
# QDPR                                                   1.297505
# RFESD                                                  0.918930
# SENP5                                                 -0.296274
#
# dcc_filename  (DSP-1001660039918-D-G12.dcc, DSP-1001660039918-D-G12.dcc)  \
# KLHL42                                                 0.424460
# USP24                                                  0.425023
# QDPR                                                   0.841663
# RFESD                                                  0.578924
# SENP5                                                  0.682312
#
# dcc_filename  (DSP-1001660039918-D-H02.dcc, DSP-1001660039918-D-H02.dcc)  \
# KLHL42                                                 1.028397
# USP24                                                  1.028954
# QDPR                                                   1.640071
# RFESD                                                  1.182964
# SENP5                                                  1.286454
#
# dcc_filename  (DSP-1001660039918-D-H03.dcc, DSP-1001660039918-D-H03.dcc)  \
# KLHL42                                                 1.106481
# USP24                                                  0.587594
# QDPR                                                   1.438831
# RFESD                                                  0.741623
# SENP5                                                  0.845129
#
# dcc_filename  (DSP-1001660039918-D-H04.dcc, DSP-1001660039918-D-H04.dcc)  \
# KLHL42                                                 0.755932
# USP24                                                  0.490417
# QDPR                                                   1.572116
# RFESD                                                  0.644450
# SENP5                                                  0.747961
#
# dcc_filename  (DSP-1001660039918-D-H06.dcc, DSP-1001660039918-D-H06.dcc)  \
# KLHL42                                                 1.032508
# USP24                                                  0.532621
# QDPR                                                   1.891291
# RFESD                                                  0.686660
# SENP5                                                  0.790176
#
# dcc_filename  (DSP-1001660039918-D-H07.dcc, DSP-1001660039918-D-H07.dcc)  \
# KLHL42                                                 0.861244
# USP24                                                  0.861798
# QDPR                                                   1.654195
# RFESD                                                  1.015844
# SENP5                                                  0.664157
#
# dcc_filename  (DSP-1001660039918-D-H09.dcc, DSP-1001660039918-D-H09.dcc)  \
# KLHL42                                                 1.053487
# USP24                                                  0.317909
# QDPR                                                   1.264687
# RFESD                                                  0.471948
# SENP5                                                  0.575465
#
# dcc_filename  (DSP-1001660039918-D-H11.dcc, DSP-1001660039918-D-H11.dcc)  \
# KLHL42                                                 0.494380
# USP24                                                  0.494936
# QDPR                                                   1.293574
# RFESD                                                  0.648954
# SENP5                                                  1.019427
#
# dcc_filename  (DSP-1001660039918-D-H12.dcc, DSP-1001660039918-D-H12.dcc)
# KLHL42                                                 0.596216
# USP24                                                  0.596773
# QDPR                                                   1.453029
# RFESD                                                  0.368548
# SENP5                                                  0.472034
#
# [5 rows x 706 columns]

# %%
geomx_data_w_metadata_only_T = geomx_data_w_metadata_only_T.reset_index().rename(columns={"dcc_filename": "NAME"})

# %%
geomx_data_w_metadata_only_T["NAME"] = geomx_data_w_metadata_only_T["index"]
geomx_data_w_metadata_only_T.head(5)
# Out:
# dcc_filename   index  \
# 0             KLHL42
# 1              USP24
# 2               QDPR
# 3              RFESD
# 4              SENP5
#
# dcc_filename  (DSP-1001660016604-A-A02.dcc, DSP-1001660016604-A-A02.dcc)  \
# 0                                                     -0.337138
# 1                                                      2.153997
# 2                                                      1.719573
# 3                                                     -0.438774
# 4                                                     -0.247221
#
# dcc_filename  DESCRIPTION  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# dcc_filename  (DSP-1001660016604-A-A04.dcc, DSP-1001660016604-A-A04.dcc)  \
# 0                                                     -0.337114
# 1                                                     -0.325901
# 2                                                      1.555881
# 3                                                     -0.438716
# 4                                                     -0.247224
#
# dcc_filename  (DSP-1001660016604-A-A06.dcc, DSP-1001660016604-A-A06.dcc)  \
# 0                                                      1.668845
# 1                                                      1.680060
# 2                                                      2.526595
# 3                                                      1.567219
# 4                                                      1.758754
#
# dcc_filename  (DSP-1001660016604-A-A08.dcc, DSP-1001660016604-A-A08.dcc)  \
# 0                                                      1.554319
# 1                                                      1.565534
# 2                                                      2.371073
# 3                                                      1.452664
# 4                                                      1.644249
#
# dcc_filename  (DSP-1001660016604-A-B02.dcc, DSP-1001660016604-A-B02.dcc)  \
# 0                                                      1.559261
# 1                                                      1.570476
# 2                                                      2.377800
# 3                                                      1.457598
# 4                                                     -0.247219
#
# dcc_filename  (DSP-1001660016604-A-B06.dcc, DSP-1001660016604-A-B06.dcc)  \
# 0                                                      1.802997
# 1                                                     -0.325937
# 2                                                      2.174256
# 3                                                      1.701339
# 4                                                      1.892930
#
# dcc_filename  (DSP-1001660016604-A-B08.dcc, DSP-1001660016604-A-B08.dcc)  \
# 0                                                     -0.337081
# 1                                                     -0.325869
# 2                                                      2.119520
# 3                                                     -0.438632
# 4                                                     -0.247228
#
# dcc_filename  (DSP-1001660016604-A-B10.dcc, DSP-1001660016604-A-B10.dcc)  ...  \
# 0                                                      1.672625           ...
# 1                                                      1.683840           ...
# 2                                                      2.014469           ...
# 3                                                     -0.438799           ...
# 4                                                     -0.247220           ...
#
# dcc_filename  (DSP-1001660039918-D-G12.dcc, DSP-1001660039918-D-G12.dcc)  \
# 0                                                      0.424460
# 1                                                      0.425023
# 2                                                      0.841663
# 3                                                      0.578924
# 4                                                      0.682312
#
# dcc_filename  (DSP-1001660039918-D-H02.dcc, DSP-1001660039918-D-H02.dcc)  \
# 0                                                      1.028397
# 1                                                      1.028954
# 2                                                      1.640071
# 3                                                      1.182964
# 4                                                      1.286454
#
# dcc_filename  (DSP-1001660039918-D-H03.dcc, DSP-1001660039918-D-H03.dcc)  \
# 0                                                      1.106481
# 1                                                      0.587594
# 2                                                      1.438831
# 3                                                      0.741623
# 4                                                      0.845129
#
# dcc_filename  (DSP-1001660039918-D-H04.dcc, DSP-1001660039918-D-H04.dcc)  \
# 0                                                      0.755932
# 1                                                      0.490417
# 2                                                      1.572116
# 3                                                      0.644450
# 4                                                      0.747961
#
# dcc_filename  (DSP-1001660039918-D-H06.dcc, DSP-1001660039918-D-H06.dcc)  \
# 0                                                      1.032508
# 1                                                      0.532621
# 2                                                      1.891291
# 3                                                      0.686660
# 4                                                      0.790176
#
# dcc_filename  (DSP-1001660039918-D-H07.dcc, DSP-1001660039918-D-H07.dcc)  \
# 0                                                      0.861244
# 1                                                      0.861798
# 2                                                      1.654195
# 3                                                      1.015844
# 4                                                      0.664157
#
# dcc_filename  (DSP-1001660039918-D-H09.dcc, DSP-1001660039918-D-H09.dcc)  \
# 0                                                      1.053487
# 1                                                      0.317909
# 2                                                      1.264687
# 3                                                      0.471948
# 4                                                      0.575465
#
# dcc_filename  (DSP-1001660039918-D-H11.dcc, DSP-1001660039918-D-H11.dcc)  \
# 0                                                      0.494380
# 1                                                      0.494936
# 2                                                      1.293574
# 3                                                      0.648954
# 4                                                      1.019427
#
# dcc_filename  (DSP-1001660039918-D-H12.dcc, DSP-1001660039918-D-H12.dcc)  \
# 0                                                      0.596216
# 1                                                      0.596773
# 2                                                      1.453029
# 3                                                      0.368548
# 4                                                      0.472034
#
# dcc_filename    NAME
# 0             KLHL42
# 1              USP24
# 2               QDPR
# 3              RFESD
# 4              SENP5
#
# [5 rows x 708 columns]

# %%
geomx_data_w_metadata_only_T.drop("index", axis=1, inplace=True)

# %%
geomx_data_w_metadata_only_T.head(5)
# Out:
# dcc_filename  (DSP-1001660016604-A-A02.dcc, DSP-1001660016604-A-A02.dcc)  \
# 0                                                     -0.337138
# 1                                                      2.153997
# 2                                                      1.719573
# 3                                                     -0.438774
# 4                                                     -0.247221
#
# dcc_filename  DESCRIPTION  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# dcc_filename  (DSP-1001660016604-A-A04.dcc, DSP-1001660016604-A-A04.dcc)  \
# 0                                                     -0.337114
# 1                                                     -0.325901
# 2                                                      1.555881
# 3                                                     -0.438716
# 4                                                     -0.247224
#
# dcc_filename  (DSP-1001660016604-A-A06.dcc, DSP-1001660016604-A-A06.dcc)  \
# 0                                                      1.668845
# 1                                                      1.680060
# 2                                                      2.526595
# 3                                                      1.567219
# 4                                                      1.758754
#
# dcc_filename  (DSP-1001660016604-A-A08.dcc, DSP-1001660016604-A-A08.dcc)  \
# 0                                                      1.554319
# 1                                                      1.565534
# 2                                                      2.371073
# 3                                                      1.452664
# 4                                                      1.644249
#
# dcc_filename  (DSP-1001660016604-A-B02.dcc, DSP-1001660016604-A-B02.dcc)  \
# 0                                                      1.559261
# 1                                                      1.570476
# 2                                                      2.377800
# 3                                                      1.457598
# 4                                                     -0.247219
#
# dcc_filename  (DSP-1001660016604-A-B06.dcc, DSP-1001660016604-A-B06.dcc)  \
# 0                                                      1.802997
# 1                                                     -0.325937
# 2                                                      2.174256
# 3                                                      1.701339
# 4                                                      1.892930
#
# dcc_filename  (DSP-1001660016604-A-B08.dcc, DSP-1001660016604-A-B08.dcc)  \
# 0                                                     -0.337081
# 1                                                     -0.325869
# 2                                                      2.119520
# 3                                                     -0.438632
# 4                                                     -0.247228
#
# dcc_filename  (DSP-1001660016604-A-B10.dcc, DSP-1001660016604-A-B10.dcc)  \
# 0                                                      1.672625
# 1                                                      1.683840
# 2                                                      2.014469
# 3                                                     -0.438799
# 4                                                     -0.247220
#
# dcc_filename  (DSP-1001660016604-A-B12.dcc, DSP-1001660016604-A-B12.dcc)  ...  \
# 0                                                      1.640225           ...
# 1                                                     -0.325920           ...
# 2                                                      1.974573           ...
# 3                                                      1.538593           ...
# 4                                                      1.730138           ...
#
# dcc_filename  (DSP-1001660039918-D-G12.dcc, DSP-1001660039918-D-G12.dcc)  \
# 0                                                      0.424460
# 1                                                      0.425023
# 2                                                      0.841663
# 3                                                      0.578924
# 4                                                      0.682312
#
# dcc_filename  (DSP-1001660039918-D-H02.dcc, DSP-1001660039918-D-H02.dcc)  \
# 0                                                      1.028397
# 1                                                      1.028954
# 2                                                      1.640071
# 3                                                      1.182964
# 4                                                      1.286454
#
# dcc_filename  (DSP-1001660039918-D-H03.dcc, DSP-1001660039918-D-H03.dcc)  \
# 0                                                      1.106481
# 1                                                      0.587594
# 2                                                      1.438831
# 3                                                      0.741623
# 4                                                      0.845129
#
# dcc_filename  (DSP-1001660039918-D-H04.dcc, DSP-1001660039918-D-H04.dcc)  \
# 0                                                      0.755932
# 1                                                      0.490417
# 2                                                      1.572116
# 3                                                      0.644450
# 4                                                      0.747961
#
# dcc_filename  (DSP-1001660039918-D-H06.dcc, DSP-1001660039918-D-H06.dcc)  \
# 0                                                      1.032508
# 1                                                      0.532621
# 2                                                      1.891291
# 3                                                      0.686660
# 4                                                      0.790176
#
# dcc_filename  (DSP-1001660039918-D-H07.dcc, DSP-1001660039918-D-H07.dcc)  \
# 0                                                      0.861244
# 1                                                      0.861798
# 2                                                      1.654195
# 3                                                      1.015844
# 4                                                      0.664157
#
# dcc_filename  (DSP-1001660039918-D-H09.dcc, DSP-1001660039918-D-H09.dcc)  \
# 0                                                      1.053487
# 1                                                      0.317909
# 2                                                      1.264687
# 3                                                      0.471948
# 4                                                      0.575465
#
# dcc_filename  (DSP-1001660039918-D-H11.dcc, DSP-1001660039918-D-H11.dcc)  \
# 0                                                      0.494380
# 1                                                      0.494936
# 2                                                      1.293574
# 3                                                      0.648954
# 4                                                      1.019427
#
# dcc_filename  (DSP-1001660039918-D-H12.dcc, DSP-1001660039918-D-H12.dcc)  \
# 0                                                      0.596216
# 1                                                      0.596773
# 2                                                      1.453029
# 3                                                      0.368548
# 4                                                      0.472034
#
# dcc_filename    NAME
# 0             KLHL42
# 1              USP24
# 2               QDPR
# 3              RFESD
# 4              SENP5
#
# [5 rows x 707 columns]

# %%
geomx_data_w_metadata_only_T["NAME"] = geomx_data_w_metadata_only_T.index

# Step 2: Reset the index, keeping the old index in the new column
geomx_data_w_metadata_only_T.reset_index(drop=True, inplace=True)

# Step 3: Optionally, you can also initialize the "DESCRIPTION" column as NaN, if needed
geomx_data_w_metadata_only_T["DESCRIPTION"] = np.nan

# %%
last_two_columns = geomx_data_w_metadata_only_T.iloc[:, -2:]

# Step 2: Get the rest of the columns excluding the last two
remaining_columns = geomx_data_w_metadata_only_T.iloc[:, :-2]

# Step 3: Concatenate the last two columns to the front
geomx_data_w_metadata_only_T = pd.concat([last_two_columns, remaining_columns], axis=1)

# Step 4: Optional: You can reset the index if needed (to avoid any indexing issues)
geomx_data_w_metadata_only_T.reset_index(drop=True, inplace=True)

# %%
geomx_data_w_metadata_only_T.head(3)
# Out:
# dcc_filename  (DSP-1001660039918-D-H12.dcc, DSP-1001660039918-D-H12.dcc)  \
# 0                                                      0.596216
# 1                                                      0.596773
# 2                                                      1.453029
#
# dcc_filename  NAME  \
# 0                0
# 1                1
# 2                2
#
# dcc_filename  (DSP-1001660016604-A-A02.dcc, DSP-1001660016604-A-A02.dcc)  \
# 0                                                     -0.337138
# 1                                                      2.153997
# 2                                                      1.719573
#
# dcc_filename  DESCRIPTION  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
#
# dcc_filename  (DSP-1001660016604-A-A04.dcc, DSP-1001660016604-A-A04.dcc)  \
# 0                                                     -0.337114
# 1                                                     -0.325901
# 2                                                      1.555881
#
# dcc_filename  (DSP-1001660016604-A-A06.dcc, DSP-1001660016604-A-A06.dcc)  \
# 0                                                      1.668845
# 1                                                      1.680060
# 2                                                      2.526595
#
# dcc_filename  (DSP-1001660016604-A-A08.dcc, DSP-1001660016604-A-A08.dcc)  \
# 0                                                      1.554319
# 1                                                      1.565534
# 2                                                      2.371073
#
# dcc_filename  (DSP-1001660016604-A-B02.dcc, DSP-1001660016604-A-B02.dcc)  \
# 0                                                      1.559261
# 1                                                      1.570476
# 2                                                      2.377800
#
# dcc_filename  (DSP-1001660016604-A-B06.dcc, DSP-1001660016604-A-B06.dcc)  \
# 0                                                      1.802997
# 1                                                     -0.325937
# 2                                                      2.174256
#
# dcc_filename  (DSP-1001660016604-A-B08.dcc, DSP-1001660016604-A-B08.dcc)  ...  \
# 0                                                     -0.337081           ...
# 1                                                     -0.325869           ...
# 2                                                      2.119520           ...
#
# dcc_filename  (DSP-1001660039918-D-G10.dcc, DSP-1001660039918-D-G10.dcc)  \
# 0                                                      1.359068
# 1                                                     -0.552626
# 2                                                      1.313898
#
# dcc_filename  (DSP-1001660039918-D-G11.dcc, DSP-1001660039918-D-G11.dcc)  \
# 0                                                      0.764414
# 1                                                      0.764974
# 2                                                      1.297505
#
# dcc_filename  (DSP-1001660039918-D-G12.dcc, DSP-1001660039918-D-G12.dcc)  \
# 0                                                      0.424460
# 1                                                      0.425023
# 2                                                      0.841663
#
# dcc_filename  (DSP-1001660039918-D-H02.dcc, DSP-1001660039918-D-H02.dcc)  \
# 0                                                      1.028397
# 1                                                      1.028954
# 2                                                      1.640071
#
# dcc_filename  (DSP-1001660039918-D-H03.dcc, DSP-1001660039918-D-H03.dcc)  \
# 0                                                      1.106481
# 1                                                      0.587594
# 2                                                      1.438831
#
# dcc_filename  (DSP-1001660039918-D-H04.dcc, DSP-1001660039918-D-H04.dcc)  \
# 0                                                      0.755932
# 1                                                      0.490417
# 2                                                      1.572116
#
# dcc_filename  (DSP-1001660039918-D-H06.dcc, DSP-1001660039918-D-H06.dcc)  \
# 0                                                      1.032508
# 1                                                      0.532621
# 2                                                      1.891291
#
# dcc_filename  (DSP-1001660039918-D-H07.dcc, DSP-1001660039918-D-H07.dcc)  \
# 0                                                      0.861244
# 1                                                      0.861798
# 2                                                      1.654195
#
# dcc_filename  (DSP-1001660039918-D-H09.dcc, DSP-1001660039918-D-H09.dcc)  \
# 0                                                      1.053487
# 1                                                      0.317909
# 2                                                      1.264687
#
# dcc_filename  (DSP-1001660039918-D-H11.dcc, DSP-1001660039918-D-H11.dcc)
# 0                                                      0.494380
# 1                                                      0.494936
# 2                                                      1.293574
#
# [3 rows x 707 columns]

# %%
# Columns you want first
first_cols = ["NAME", "DESCRIPTION"]

# Keep only those that actually exist
first_cols = [c for c in first_cols if c in geomx_data_w_metadata_only_T.columns]

# Reorder
geomx_data_w_metadata_only_T = geomx_data_w_metadata_only_T[
    first_cols + [c for c in geomx_data_w_metadata_only_T.columns if c not in first_cols]
]

geomx_data_w_metadata_only_T.head(3)
# Out:
# dcc_filename  NAME  DESCRIPTION  \
# 0                0          NaN
# 1                1          NaN
# 2                2          NaN
#
# dcc_filename  (DSP-1001660039918-D-H12.dcc, DSP-1001660039918-D-H12.dcc)  \
# 0                                                      0.596216
# 1                                                      0.596773
# 2                                                      1.453029
#
# dcc_filename  (DSP-1001660016604-A-A02.dcc, DSP-1001660016604-A-A02.dcc)  \
# 0                                                     -0.337138
# 1                                                      2.153997
# 2                                                      1.719573
#
# dcc_filename  (DSP-1001660016604-A-A04.dcc, DSP-1001660016604-A-A04.dcc)  \
# 0                                                     -0.337114
# 1                                                     -0.325901
# 2                                                      1.555881
#
# dcc_filename  (DSP-1001660016604-A-A06.dcc, DSP-1001660016604-A-A06.dcc)  \
# 0                                                      1.668845
# 1                                                      1.680060
# 2                                                      2.526595
#
# dcc_filename  (DSP-1001660016604-A-A08.dcc, DSP-1001660016604-A-A08.dcc)  \
# 0                                                      1.554319
# 1                                                      1.565534
# 2                                                      2.371073
#
# dcc_filename  (DSP-1001660016604-A-B02.dcc, DSP-1001660016604-A-B02.dcc)  \
# 0                                                      1.559261
# 1                                                      1.570476
# 2                                                      2.377800
#
# dcc_filename  (DSP-1001660016604-A-B06.dcc, DSP-1001660016604-A-B06.dcc)  \
# 0                                                      1.802997
# 1                                                     -0.325937
# 2                                                      2.174256
#
# dcc_filename  (DSP-1001660016604-A-B08.dcc, DSP-1001660016604-A-B08.dcc)  ...  \
# 0                                                     -0.337081           ...
# 1                                                     -0.325869           ...
# 2                                                      2.119520           ...
#
# dcc_filename  (DSP-1001660039918-D-G10.dcc, DSP-1001660039918-D-G10.dcc)  \
# 0                                                      1.359068
# 1                                                     -0.552626
# 2                                                      1.313898
#
# dcc_filename  (DSP-1001660039918-D-G11.dcc, DSP-1001660039918-D-G11.dcc)  \
# 0                                                      0.764414
# 1                                                      0.764974
# 2                                                      1.297505
#
# dcc_filename  (DSP-1001660039918-D-G12.dcc, DSP-1001660039918-D-G12.dcc)  \
# 0                                                      0.424460
# 1                                                      0.425023
# 2                                                      0.841663
#
# dcc_filename  (DSP-1001660039918-D-H02.dcc, DSP-1001660039918-D-H02.dcc)  \
# 0                                                      1.028397
# 1                                                      1.028954
# 2                                                      1.640071
#
# dcc_filename  (DSP-1001660039918-D-H03.dcc, DSP-1001660039918-D-H03.dcc)  \
# 0                                                      1.106481
# 1                                                      0.587594
# 2                                                      1.438831
#
# dcc_filename  (DSP-1001660039918-D-H04.dcc, DSP-1001660039918-D-H04.dcc)  \
# 0                                                      0.755932
# 1                                                      0.490417
# 2                                                      1.572116
#
# dcc_filename  (DSP-1001660039918-D-H06.dcc, DSP-1001660039918-D-H06.dcc)  \
# 0                                                      1.032508
# 1                                                      0.532621
# 2                                                      1.891291
#
# dcc_filename  (DSP-1001660039918-D-H07.dcc, DSP-1001660039918-D-H07.dcc)  \
# 0                                                      0.861244
# 1                                                      0.861798
# 2                                                      1.654195
#
# dcc_filename  (DSP-1001660039918-D-H09.dcc, DSP-1001660039918-D-H09.dcc)  \
# 0                                                      1.053487
# 1                                                      0.317909
# 2                                                      1.264687
#
# dcc_filename  (DSP-1001660039918-D-H11.dcc, DSP-1001660039918-D-H11.dcc)
# 0                                                      0.494380
# 1                                                      0.494936
# 2                                                      1.293574
#
# [3 rows x 707 columns]

# %%
geomx_data_w_metadata_only_T.to_csv("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged_new/gsea_fibr_expression_stromal_pre_post.txt", sep="\t", index=False)

# %%
len(geomx_data_w_metadata_only_T.columns)
# Out:
# 707

# %%
labels = fibr_gene_expression_modified["Segment_geomx"].astype(str).tolist()
classes = sorted(set(labels))
num_samples = len(labels)
num_classes = len(classes)

with open("/Users/nikamikhailava/Desktop/Lab_stuff/batch_merged_new/fibroblasts_labels_for_gsea_pre_post.cls", "w") as f:
    # Write number of samples, number of classes, and number of columns (usually 1)
    f.write(f"{num_samples} {num_classes} 1\n")
    
    # Write the class names in the second line (no extra spaces at the end)
    f.write(f"# {' '.join(classes)}\n")
    
    # Write the actual class labels for each sample, space-separated
    f.write(' '.join(labels) + "\n")
