# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr, wilcoxon
import plotly.express as px
import plotly.graph_objects as go
import nbformat

from scipy.stats import ttest_ind, f_oneway
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib_venn import venn2
import os

# %%
fibr_gene_expression_modified=pd.read_csv("/Users/nikamikhailava/Desktop/batch_merged_new/fibroblasts_gene_expression_data_new_batch_merged.csv")
fibr_gene_expression_modified_T=fibr_gene_expression_modified.T

# %%
fibr_gene_expression_modified=fibr_gene_expression_modified.set_index(['Unnamed: 0'])

# %%
fibr_gene_expression_modified_T=fibr_gene_expression_modified.T
fibr_gene_expression_modified_T = fibr_gene_expression_modified_T.reset_index()
fibr_gene_expression_modified_T
# Out:
# Unnamed: 0                        index    SAMD11     NOC2L    KLHL17  \
# 0           DSP-1001660016604-A-A02.dcc  1.395991  1.907436  1.506498
# 1           DSP-1001660016604-A-A03.dcc  1.260101  1.487834  1.372068
# 2           DSP-1001660016604-A-A04.dcc  1.224783  1.724003  1.333149
# 3           DSP-1001660016604-A-A05.dcc  1.032495  1.168011  1.440325
# 4           DSP-1001660016604-A-A06.dcc  0.885513  1.403719  0.997214
# ..                                  ...       ...       ...       ...
# 439         DSP-1001660037247-C-D01.dcc  1.437959  1.440393  1.436729
# 440         DSP-1001660037247-C-D02.dcc  0.945847  1.243403  0.944546
# 441         DSP-1001660037247-C-D03.dcc -0.115866  0.009407 -0.109719
# 442         DSP-1001660037247-C-D04.dcc  0.912336  1.440847  0.911072
# 443         DSP-1001660037247-C-D06.dcc  1.021921  1.023717  1.020654
#
# Unnamed: 0   PLEKHN1     PERM1      HES4     ISG15      AGRN    RNF223  ...  \
# ...

# %%
fibr_gene_expression_modified_T = fibr_gene_expression_modified_T.rename(columns={'index': 'dcc_filename'})

# %%
metadata=pd.read_csv("/Users/nikamikhailava/Desktop/batch_merged_new/batch_merged_geomx_metadata.csv")

# %%
merged_df = fibr_gene_expression_modified_T.merge(metadata, on='dcc_filename', how='left')
merged_df["Segment"]
# Out:
# 0      stroma
# 1         NaN
# 2      stroma
# 3       tumor
# 4         NaN
#         ...
# 439    stroma
# 440    stroma
# 441     tumor
# 442    stroma
# 443    stroma
# Name: Segment, Length: 444, dtype: object

# %%
merged_df=merged_df.to_csv("/Users/nikamikhailava/Desktop/batch_merged_new/fibroblasts_gene_expression_data_new_batch_merged_with_metadata.csv", index=False)
