# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr, wilcoxon
import plotly.express as px
import plotly.graph_objects as go
import nbformat

from scipy.stats import ttest_ind, f_oneway
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib_venn import venn2
import os

# %%
folder_path="/Users/nikamikhailava/Desktop/batch_merged"

non_grata=["PFS", "PFS_months", "R0", "OS"]
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        
        # Load the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        
        # Drop the non-grata columns if they exist in the DataFrame
        df.drop(columns=[col for col in non_grata if col in df.columns], inplace=True)
        
        # Save the modified DataFrame back to the CSV file
        df.to_csv(file_path, index=False)

        print(f"Processed {filename}")
# Out:
# Processed batch2_ssgsea_norm_harmony_batch_corr_deconv_Fibroblasts_msigdb.csv
# Processed batch1_ssgsea_norm_harmony_batch_corr_deconv_Fibroblasts_msigdb.csv
# Processed batch2_ssgsea_norm_harmony_batch_corr_deconv_tumor_msigdb.csv
# Processed batch1_geomx_harmony_corr_expr.csv
# Processed batch2_filtered_data_transposed.csv
# Processed batch2_geomx_harmony_corr_expr.csv
# Processed batch1_geomx_metadata.csv
# Processed batch1_bp_res_mid_lvl_ct_ct_fraction.csv
# Processed batch2_geomx_metadata.csv
# Processed batch1_ssgsea_norm_harmony_batch_corr_all_msigdb.csv
# Processed batch2_genes_of_interest.csv
# Processed 9_eyemt_patient_clinical_data.csv
# Processed batch2_ssgsea_norm_harmony_batch_corr_all_msigdb.csv
# Processed batch2_bp_res_mid_lvl_ct_ct_fraction.csv
# Processed batch1_ssgsea_norm_harmony_batch_corr_deconv_tumor_msigdb.csv

# %%
df = pd.read_csv("batch1_geomx_metadata.csv")
df.drop(columns=[col for col in non_grata if col in df.columns], inplace=True)
df.to_csv("batch1_geomx_metadata.csv", index=False)
print("Processed ")
df
# Out:
# Processed
#                     dcc_filename                               Slide_Name  \
# 0    DSP-1001660016606-G-A02.dcc  NACT_TSI_2022_Batch8_13097-57209_140623
# 1    DSP-1001660016606-G-A03.dcc  NACT_TSI_2022_Batch8_13097-57209_140623
# 2    DSP-1001660016606-G-A04.dcc  NACT_TSI_2022_Batch8_13097-57209_140623
# 3    DSP-1001660016606-G-A05.dcc  NACT_TSI_2022_Batch8_13097-57209_140623
# 4    DSP-1001660016606-G-A06.dcc  NACT_TSI_2022_Batch8_13097-57209_140623
# ..                           ...                                      ...
# 305  DSP-1001660016658-B-H08.dcc         NACT_TSI_2022_Batch5_S084_230523
# 306  DSP-1001660016658-B-H09.dcc         NACT_TSI_2022_Batch5_S084_230523
# 307  DSP-1001660016658-B-H10.dcc         NACT_TSI_2022_Batch5_S084_230523
# 308  DSP-1001660016658-B-H11.dcc         NACT_TSI_2022_Batch5_S084_230523
# 309  DSP-1001660016658-B-H12.dcc         NACT_TSI_2022_Batch5_S084_230523
#
#         Sample Segment  Roi             Aoi      area  nuclei NACT_status  \
# 0    S053_post  stroma    1  stroma-aoi-001  27922.80     227        post
# 1    S053_post   tumor    1   tumor-aoi-001  19023.63     131        post
# 2    S053_post  stroma    2  stroma-aoi-001  33159.35     188        post
# 3    S053_post   tumor    2   tumor-aoi-001  21852.52     139        post
# 4    S053_post  stroma    3  stroma-aoi-001  38863.40     189        post
# ..         ...     ...  ...             ...       ...     ...         ...
# 305   S084_pre  stroma   11  stroma-aoi-001  24315.34     177         pre
# 306   S084_pre   tumor   11   tumor-aoi-001  17641.44     142         pre
# 307   S084_pre  stroma   12  stroma-aoi-001  50141.39     232         pre
# 308   S084_pre   tumor   12   tumor-aoi-001  10281.83      77         pre
# 309   S084_pre  stroma   13  stroma-aoi-001  29736.35     160         pre
#
#     Patient     Site Annotation_cell  UMAP1_harmony_batch_corr  \
# 0      S053  Omentum  posCD8_posIBA1                  0.794573
# 1      S053  Omentum  posCD8_posIBA1                  2.214970
# 2      S053  Omentum  posCD8_posIBA1                  1.085109
# 3      S053  Omentum  posCD8_posIBA1                  2.348271
# 4      S053  Omentum  posCD8_posIBA1                  1.287827
# ..      ...      ...             ...                       ...
# 305    S084    Adnex  posCD8_posIBA1                  0.453973
# 306    S084    Adnex  posCD8_posIBA1                 -0.315918
# 307    S084    Adnex  posCD8_posIBA1                  0.368944
# 308    S084    Adnex  posCD8_posIBA1                 -0.207591
# 309    S084    Adnex  posCD8_posIBA1                  1.033257
#
#      UMAP2_harmony_batch_corr  tSNE1_harmony_batch_corr  \
# 0                   -3.189869                 -3.847626
# 1                    4.387641                 -0.483552
# 2                   -3.414700                 -3.420880
# 3                    4.468682                 -0.820358
# 4                   -3.338168                 -3.264500
# ..                        ...                       ...
# 305                 -2.786184                 -1.603120
# 306                  4.802006                  2.475208
# 307                 -2.791319                 -1.472896
# 308                  4.624220                  1.919430
# 309                 -2.895027                 -1.770278
#
#      tSNE2_harmony_batch_corr
# 0                   -6.147862
# 1                   10.893174
# 2                   -5.879995
# 3                   11.383190
# 4                   -5.409131
# ..                        ...
# 305                 -6.496916
# 306                 11.815276
# 307                 -6.896271
# 308                 11.321238
# 309                 -5.827703
#
# [310 rows x 16 columns]

# %%
metadata = pd.read_csv("9_eyemt_patient_clinical_data.csv")

# Assume `data.csv` is your dataset to which you want to add the columns
data = pd.read_csv("batch2_geomx_metadata.csv")

# Merge the datasets on the 'sample_id' column (you should replace 'sample_id' with the actual name of the column)
merged_data = pd.merge(data, metadata[['Sample',"PFS_quartile","OS_quartile","HRP_status","BRCA_status"]], on='Sample', how='left')

# Save the merged dataset back to a new CSV
merged_data.to_csv("batch2_geomx_metadata.csv", index=False)

print("Merge complete and saved to 'batch2_geomx_metadata.csv'")
# Out:
# Merge complete and saved to 'batch2_geomx_metadata.csv'

# %%
batch1_df = pd.read_csv("batch1_ssgsea_norm_harmony_batch_corr_deconv_tumor_msigdb.csv")
batch2_df = pd.read_csv("batch2_ssgsea_norm_harmony_batch_corr_deconv_tumor_msigdb.csv")
            
            # Append the rows of batch2 to batch1
merged_df = pd.concat([batch1_df, batch2_df], ignore_index=True)

merged_df.to_csv("batch_merged_ssgsea_norm_harmony_batch_corr_deconv_tumor_msigdb.csv", index=False)

# %%
batch1_df_T=pd.read_csv("batch1_geomx_harmony_corr_expr.csv").T
batch2_df_T=pd.read_csv("batch2_geomx_harmony_corr_expr.csv").T

# %%
batch1_df_T.columns = batch1_df_T.iloc[0]  # Set the first row as column names
batch2_df_T.columns = batch2_df_T.iloc[0]

# %%
batch2_df_T.reset_index(inplace=True)
batch2_df_T.rename(columns={'index': 'dcc_filename'}, inplace=True)

# %%
batch1_df_T.reset_index(inplace=True)
batch1_df_T.rename(columns={'index': 'dcc_filename'}, inplace=True)

# %%
batch1_df_T=batch1_df_T.drop(0)

# %%
batch1_df_T.reset_index(drop=True, inplace=True)

# %%
merged_df = pd.concat([batch1_df_T, batch2_df_T], ignore_index=True)

merged_df.to_csv("batch_merged_geomx_harmony_corr_expr_transpose.csv", index=False)
merged_df
# Out:
# gene_name                 dcc_filename       A2M     ACADM     ACADS  \
# 0          DSP.1001660016606.G.A02.dcc  6.804666   3.81377  3.094522
# 1          DSP.1001660016606.G.A03.dcc  6.260479   4.09892  2.754026
# 2          DSP.1001660016606.G.A04.dcc  6.558231  3.995816   3.35482
# 3          DSP.1001660016606.G.A05.dcc  6.372312  3.182476  2.866057
# 4          DSP.1001660016606.G.A06.dcc  7.417367  3.226799  2.810282
# ..                                 ...       ...       ...       ...
# 499        DSP.1001660037247.C.D02.dcc  8.166184  5.241664  3.124489
# 500        DSP.1001660037247.C.D03.dcc  6.376363   5.55236  2.214444
# 501        DSP.1001660037247.C.D04.dcc  5.965432  4.531758  3.336801
# 502        DSP.1001660037247.C.D05.dcc  4.274683  4.829125  4.450223
# 503        DSP.1001660037247.C.D06.dcc  8.519846  4.297684   2.61166
#
# gene_name     ACAT1    ACVRL1     PSEN1       ADA      SGCA     ADRB2  ...  \
# 0          3.164409  3.379704  4.040574  2.899794  3.971268  1.660338  ...
# 1          3.695262  3.204526   4.71378  2.037078  3.807079  1.459433  ...
# 2          3.765523  2.918882  3.908741  3.160093  3.933863  2.369323  ...
# 3          3.848748  1.562825   4.43985  2.001105  4.093993  1.666247  ...
# 4          4.366523  3.352077  3.631273  2.465758  3.329628  1.619624  ...
# ..              ...       ...       ...       ...       ...       ...  ...
# 499        3.526732  3.990766  4.529707  2.097933  3.164388  2.191627  ...
# 500        5.236922  3.291828  5.162804  1.452677  2.908834  0.359455  ...
# 501         4.18214  4.394296   2.16528   3.05281   0.85134  2.393427  ...
# 502        5.702187   2.66274  5.174575  2.488751  3.088751  0.339813  ...
# 503         3.42571  4.334616  5.403841  3.302788  3.315302  2.732738  ...
#
# gene_name     RPEL1   SLC12A6   SPATA21    SYCP2L     FGF10       IL3  \
# 0               NaN       NaN       NaN       NaN       NaN       NaN
# 1               NaN       NaN       NaN       NaN       NaN       NaN
# 2               NaN       NaN       NaN       NaN       NaN       NaN
# 3               NaN       NaN       NaN       NaN       NaN       NaN
# 4               NaN       NaN       NaN       NaN       NaN       NaN
# ..              ...       ...       ...       ...       ...       ...
# 499        1.682951  2.486022  1.303624  4.220623  3.404106  1.639313
# 500        2.603953  1.448833  1.971167  2.171534  1.837595  0.993433
# 501        3.660318   2.69628  1.463408  2.607464  3.337978   2.27393
# 502        2.165921  2.484907   2.90509  1.682048  2.462543  2.462948
# 503        2.258584  2.635201  3.410152  1.616437   3.27658  3.276985
#
# gene_name       IL5      MBL2      ARG1      CCL7
# 0               NaN       NaN       NaN       NaN
# 1               NaN       NaN       NaN       NaN
# 2               NaN       NaN       NaN       NaN
# 3               NaN       NaN       NaN       NaN
# 4               NaN       NaN       NaN       NaN
# ..              ...       ...       ...       ...
# 499        0.528117  1.784708  1.268932  1.171722
# 500        2.067794  3.294537  0.338434  0.994699
# 501        4.099109  1.475635   1.92379   1.82658
# 502        0.763774  0.365711  2.561423  0.535245
# 503         0.56825  0.923731  1.381378  0.779602
#
# [504 rows x 18357 columns]
